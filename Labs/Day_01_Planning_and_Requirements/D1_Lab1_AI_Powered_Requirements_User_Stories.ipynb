# %% [markdown]
# # Day 1 - Lab 1: AI-Powered Requirements & User Stories
#
# **Objective:** Use a Large Language Model (LLM) to decompose a vague problem statement into structured features, user personas, and Agile user stories, culminating in a machine-readable JSON artifact.
#
# **Estimated Time:** 90 minutes
#
# **Introduction:**
# Welcome to the first hands-on lab of the AI-Driven Software Engineering Program! All great software projects begin with a clear understanding of the problem to be solved. In this lab, you will take on the role of a tech lead or product manager and use an LLM as a co-pilot to transform a simple, high-level problem into a set of well-defined, actionable requirements. This process is fundamental to ensuring that the team builds the *right* product.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# This initial block sets up our environment. It adds the project's root directory to the Python path, allowing us to import our custom `utils.py` script. We then initialize the connection to our Large Language Model (LLM).
#
# **Model Selection:**
# Our `utils.py` script is configured to work with multiple AI providers. You can change the `model_name` parameter in the `setup_llm_client()` function to any of the models listed in the `RECOMMENDED_MODELS` dictionary in `utils.py`. For example, to use a Hugging Face model, you could change the line to: `client, model_name, api_provider = setup_llm_client(model_name="meta-llama/Llama-3.3-70B-Instruct")`
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client for our chosen LLM.
# - `get_completion()`: To send a prompt to the LLM and get a response.
# - `save_artifact()`: To save our generated requirements to a file.

# %%
import sys
import os
import json

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Assumes the notebook is in 'labs/Day_01_.../'
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    # Fallback for different execution environments
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact

# Initialize the LLM client. You can change the model here.
# For example: setup_llm_client(model_name="gemini-2.5-flash")
client, model_name, api_provider = setup_llm_client(model_name="gpt-4o")
# Out:
# ✅ LLM Client configured: Using 'openai' with model 'gpt-4o'

# %% [markdown]
# ## Step 2: The Problem Statement
#
# Every project starts with a problem. Our problem is a common one in many organizations:
#
# > **"We need a tool to help our company's new hires get up to speed."**
#
# This statement is intentionally vague. Our job is to use the LLM to add structure and detail to it.

# %%
problem_statement = "Our organization faces challenges in efficiently onboarding new hires, resulting in delayed productivity and inconsistent knowledge transfer. We require a comprehensive digital onboarding tool that streamlines the orientation process, delivers personalized learning paths, tracks progress, and provides easy access to essential resources. The solution should facilitate faster integration of new employees, ensure compliance with company policies, and enable managers to monitor onboarding effectiveness through actionable analytics."

# %% [markdown]
# ## Step 3: The Challenges
#
# Complete the following challenges in order. Each one builds upon the last, increasing in technical complexity and value.

# %% [markdown]
# ### Challenge 1 (Foundational): Brainstorming Features
#
# **Task:** Use the LLM to brainstorm a list of potential features and user personas based on the problem statement.
#
# **Instructions:**
# 1. Write a simple prompt that asks the LLM to brainstorm features for the onboarding tool.
# 2. Write a second prompt to identify three distinct user personas who would use this tool.
# 3. Run both prompts and review the markdown output.
#
# **Expected Quality:** The output should be a simple, readable markdown list of features and a description of the personas. This is a good first step but lacks the structure needed for automation.

# %%
# This prompt is direct and open-ended, encouraging the LLM to be creative.
features_prompt = f"""
You are an Enterprise Architect following TOGAF principles. Using the following context:

Problem Statement:
{problem_statement}

Your task:
- Brainstorm a list of 20 high-value features for a new hire onboarding tool.
- Ensure the features align with TOGAF principles, such as modularity, scalability, interoperability, and alignment with business goals.
- Refine the features to address any gaps or risks in enterprise architecture.

Output the refined list of features as a simple markdown list.
"""

print("--- Brainstorming Features ---")
brainstormed_features = get_completion(features_prompt, client, model_name, api_provider)
print(brainstormed_features)

# This prompt asks for specific roles to ground the brainstorming in user-centric thinking.
personas_prompt = f"""
You are an IT Service Manager following ITIL principles. Using the following context:

Problem Statement:
{problem_statement}

Your task:
- Identify three distinct and impactful user personas who would benefit from and interact with this tool.
- Ensure the personas reflect ITIL principles, such as service design, service operation, and continual improvement.
- Refine the personas to ensure they align with ITIL processes, such as incident management and service request fulfillment.

Output the refined personas as a simple markdown list.
"""

print("\n--- Identifying User Personas ---")
user_personas = get_completion(personas_prompt, client, model_name, api_provider)
print(user_personas)
# Out:
# --- Brainstorming Features ---
# 1. **Personalized Learning Paths**: Customize onboarding experiences based on role, department, and employee background.
# 2. **Progress Tracking Dashboard**: Visual dashboards for new hires and managers to monitor onboarding progress.
# 3. **Compliance Module**: Automated compliance training sessions with tracking and reminders.
# 4. **Interactive Checklists**: Step-by-step onboarding tasks with due dates and notifications.
# 5. **Resource Library**: Centralized access to all essential documents, policies, and training materials.
# 6. **Virtual Orientation Sessions**: Live or recorded orientation sessions with interactive Q&A.
# 7. **Feedback and Surveys**: Collect new hire feedback through surveys to improve onboarding processes.
# 8. **Integrations with HR Systems**: Seamless integration with existing HR management and payroll systems.
# 9. **Role-Specific Training Modules**: Detailed training content tailored to specific roles and responsibilities.
# 10. **Mentor/Mentee Matching**: Automated pairing of new hires with experienced mentors.
# 11. **Social Integration Tools**: Features to connect new hires with their team and organization culture.
# 12. **Gamification Elements**: Points, badges, and leaderboards to increase engagement.
# 13. **Document e-Signing**: Digital signing of contracts and policy agreements.
# 14. **Mobile Access**: Mobile-friendly platform for onboarding on the go.
# 15. **Automated Reminders and Alerts**: Notifications for pending tasks and deadlines.
# 16. **Multi-Language Support**: Onboarding content available in multiple languages.
# 17. **Video Introductions**: Short video intros from team members and executives.
# 18. **Knowledge Check Quizzes**: Interactive quizzes to assess understanding of key concepts.
# 19. **Virtual Reality Tours**: VR experiences of office surroundings and facilities.
# 20. **Customizable Templates**: Pre-built templates for onboarding processes and content creation.
# 21. **Peer Networking Tools**: Features to facilitate connections among new hires.
# 22. **Onboarding Analytics and Reporting**: Detailed reports on onboarding effectiveness and areas for improvement.
# 23. **Self-Service FAQs and Chatbot**: AI-driven support for common queries and issues.
# 24. **Task Automation**: Automate administrative tasks like IT setup requests and workstation allocation.
# 25. **Cultural Integration Modules**: Training on company values, mission, and culture.
# 26. **Time Management Tools**: Calendar integration for scheduling training and meetings.
# 27. **Manager Dashboards**: Insights and analytics for managers to track team onboarding.
# 28. **Access to Company News and Updates**: Real-time updates and announcements from the organization.
# 29. **Scenario-Based Learning**: Simulations to practice real-world scenarios.
# 30. **Feedback Loop with Managers**: Channels for continuous feedback between new hires and managers.
#
# --- Identifying User Personas ---
# To address the challenges outlined in the problem statement, the digital onboarding tool should cater to three distinct and impactful user personas: New Employees, HR Managers, and Department Managers. Each of these personas plays a crucial role in the onboarding process and will interact with the tool to achieve specific goals.
#
# 1. **New Employee**
#    - **Role:** A new hire who is joining the organization and needs to integrate quickly and effectively into their new role.
#    - **Main Goal:** The primary goal of the new employee is to become productive as soon as possible. They need a clear understanding of the company culture, policies, and their specific job responsibilities. The digital onboarding tool will provide them with personalized learning paths, track their progress, and give them access to essential resources. This will help them feel welcomed, informed, and equipped to perform their duties efficiently.
#
# 2. **HR Manager**
#    - **Role:** An HR professional responsible for managing the onboarding process, ensuring compliance with company policies, and maintaining employee records.
#    - **Main Goal:** The HR Manager aims to streamline the onboarding process to make it more efficient and consistent across the organization. They need to ensure that all new hires receive the same level of information and training, comply with company policies, and are set up for success. The digital onboarding tool will help them automate and personalize the onboarding experience, track the progress of new hires, and generate reports on onboarding effectiveness and compliance.
#
# 3. **Department Manager**
#    - **Role:** A manager responsible for overseeing a specific department and ensuring that new team members integrate smoothly into their teams.
#    - **Main Goal:** The Department Manager's objective is to facilitate the faster integration of new employees into their teams to minimize disruptions and maximize productivity. They need to monitor the onboarding progress of new hires, provide feedback, and ensure that they are acquiring the necessary skills and knowledge to contribute effectively. The digital onboarding tool will provide them with actionable analytics and insights into the onboarding process, allowing them to identify areas for improvement and support new hires in their transition.
#
# By addressing the needs and goals of these three personas, the digital onboarding tool can significantly improve the efficiency and effectiveness of the onboarding process, leading to quicker and more successful integration of new employees into the organization.

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating Formal User Stories
#
# **Task:** Now, let's increase the value by generating structured, formal Agile User Stories.
#
# **Instructions:**
# 1. Create a new, more sophisticated prompt.
# 2. This prompt should instruct the LLM to act as a Senior Product Manager.
# 3. It must use the brainstormed features and personas from the previous step as context.
# 4. The key instruction is to generate a list of user stories, each with detailed acceptance criteria in Gherkin format (`Given/When/Then`).
# 5. **Crucially, the prompt must demand the final output be a well-formed JSON array of objects.** Each object should represent a user story and have keys like `id`, `user_story`, `persona`, and `acceptance_criteria`.
#
# > **Tip:** If the LLM's output isn't perfect JSON, try making your prompt even more specific. You can tell it, 'Do not include any text before or after the JSON array. Your response must begin with [ and end with ].'
#
# **Expected Quality:** The output should not be markdown, but a clean, parsable JSON string. This is a significant step up in value, as a JSON artifact can be automatically processed by other systems (e.g., imported into Jira).

# %%
# TODO: Create a detailed prompt string named 'json_user_stories_prompt'.
# This prompt needs to instruct the LLM to act as a Senior Product Manager and convert the
# brainstormed features and personas into a structured JSON array of user stories.
# Tip: Be very specific about the required JSON format in your prompt instructions.
# Tell it what keys to use and what the data types should be.
json_user_stories_prompt = f"""
You are a Senior Product Manager . Using the following context:

Problem Statement:
{problem_statement}

Features:
{brainstormed_features}

Personas:
{user_personas}

Your task:
- For each feature, create one user story for each  using the format: "As a [persona], I want to [do something], so that [benefit]."
- Each user story must include:
    - "id": integer, unique and sequential starting from 1
    - "persona": string, matching one of the personas above
    - "feature": string, matching one of the features above
    - "user_story": string, the user story as described above
    - "acceptance_criteria": list of 2-4 items, each in Gherkin format (Given/When/Then)
    - "priority": string, one of: High, Medium, Low

Output instructions:
- Output a valid JSON array containing one user story object for each feature-persona combination.
- Do not include any text before or after the JSON array. The response must begin with [ and end with ].
- Ensure the JSON is valid and can be parsed by Python's json.loads().

Begin.
"""

print("--- Generating User Stories as JSON ---")
json_output_str = get_completion(json_user_stories_prompt, client, model_name, api_provider, temperature=0.2)

# Let's try to parse the JSON to see if the LLM followed instructions
try:
    # The LLM might wrap the JSON in markdown fences (```json ... ```).
    # We'll clean that up before parsing.
    if '```' in json_output_str:
        json_output_str = json_output_str.split('```')[1].lstrip('json').strip()
    
    user_stories_json = json.loads(json_output_str)
    print("Successfully parsed LLM output as JSON.")
    
    if user_stories_json:
        print("\n--- Sample User Story ---")
        print(json.dumps(user_stories_json[0], indent=2))
    else:
        print("JSON array is empty.")

except (json.JSONDecodeError, TypeError, IndexError) as e:
    print(f"Error: Failed to parse LLM output as JSON. Error: {e}")
    print("LLM Output was:\n", json_output_str)
    user_stories_json = []
# Out:
# --- Generating User Stories as JSON ---
# Successfully parsed LLM output as JSON.
#
# --- Sample User Story ---
# {
#   "id": 1,
#   "persona": "New Employee",
#   "feature": "Personalized Learning Paths",
#   "user_story": "As a New Employee, I want to have a personalized learning path, so that I can focus on the most relevant information for my role.",
#   "acceptance_criteria": [
#     "Given I am a new employee, when I log into the onboarding tool, then I should see a personalized learning path based on my role.",
#     "Given I have completed a module, when I check my progress, then it should reflect the completion in my learning path."
#   ],
#   "priority": "High"
# }

# %%
user_stories_json
# Out:
# [{'id': 1,
#   'persona': 'New Employee',
#   'feature': 'Personalized Learning Paths',
#   'user_story': 'As a New Employee, I want to have a personalized learning path, so that I can focus on the most relevant information for my role.',
#   'acceptance_criteria': ['Given I am a new employee, when I log into the onboarding tool, then I should see a personalized learning path based on my role.',
#    'Given I have completed a module, when I check my progress, then it should reflect the completion in my learning path.'],
#   'priority': 'High'},
#  {'id': 2,
#   'persona': 'HR Manager',
#   'feature': 'Personalized Learning Paths',
#   'user_story': 'As an HR Manager, I want to customize learning paths for new hires, so that each employee receives training relevant to their role.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I create a new onboarding plan, then I should be able to customize learning paths based on roles.',
#    'Given a new hire is assigned a role, when they start onboarding, then they should see a learning path tailored to their role.'],
#   'priority': 'High'},
#  {'id': 3,
#   'persona': 'Department Manager',
#   'feature': 'Personalized Learning Paths',
#   'user_story': 'As a Department Manager, I want to ensure new hires have role-specific learning paths, so that they acquire the necessary skills quickly.',
#   'acceptance_criteria': ["Given I am a Department Manager, when I review a new hire's onboarding progress, then I should see their role-specific learning path.",
#    'Given a new hire completes a module, when I check their progress, then it should show updated completion status.'],
#   'priority': 'High'},
#  {'id': 4,
#   'persona': 'New Employee',
#   'feature': 'Progress Tracking Dashboard',
#   'user_story': 'As a New Employee, I want to track my onboarding progress, so that I know what tasks I have completed and what is pending.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the onboarding tool, then I should see a dashboard displaying my progress.',
#    'Given I complete a task, when I refresh the dashboard, then it should reflect the updated progress.'],
#   'priority': 'High'},
#  {'id': 5,
#   'persona': 'HR Manager',
#   'feature': 'Progress Tracking Dashboard',
#   'user_story': 'As an HR Manager, I want to monitor the progress of new hires, so that I can ensure they are on track with their onboarding.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I view the onboarding dashboard, then I should see the progress of all new hires.',
#    'Given a new hire completes a task, when I check their progress, then it should show the updated status.'],
#   'priority': 'High'},
#  {'id': 6,
#   'persona': 'Department Manager',
#   'feature': 'Progress Tracking Dashboard',
#   'user_story': 'As a Department Manager, I want to track the onboarding progress of my team members, so that I can provide support where needed.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I access the dashboard, then I should see the progress of new hires in my department.',
#    'Given a new hire is behind schedule, when I view their progress, then I should be able to identify areas where they need support.'],
#   'priority': 'High'},
#  {'id': 7,
#   'persona': 'New Employee',
#   'feature': 'Compliance Module',
#   'user_story': 'As a New Employee, I want to complete compliance training, so that I adhere to company policies.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the compliance module, then I should see a list of required training sessions.',
#    'Given I complete a compliance session, when I check my status, then it should show as completed.'],
#   'priority': 'High'},
#  {'id': 8,
#   'persona': 'HR Manager',
#   'feature': 'Compliance Module',
#   'user_story': 'As an HR Manager, I want to ensure all new hires complete compliance training, so that the organization remains compliant with regulations.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I view the compliance dashboard, then I should see the completion status of all new hires.',
#    'Given a new hire has not completed a session, when I check their compliance status, then it should show as pending.'],
#   'priority': 'High'},
#  {'id': 9,
#   'persona': 'Department Manager',
#   'feature': 'Compliance Module',
#   'user_story': 'As a Department Manager, I want to verify that my team members have completed compliance training, so that we adhere to company standards.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I access the compliance module, then I should see the training status of my team members.',
#    'Given a team member completes a session, when I check their compliance status, then it should show as completed.'],
#   'priority': 'High'},
#  {'id': 10,
#   'persona': 'New Employee',
#   'feature': 'Interactive Checklists',
#   'user_story': 'As a New Employee, I want to follow an interactive checklist, so that I complete all onboarding tasks on time.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the onboarding tool, then I should see an interactive checklist of tasks.',
#    'Given I complete a task, when I check the checklist, then it should show the task as completed.'],
#   'priority': 'High'},
#  {'id': 11,
#   'persona': 'HR Manager',
#   'feature': 'Interactive Checklists',
#   'user_story': 'As an HR Manager, I want to provide new hires with interactive checklists, so that they can complete onboarding tasks systematically.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I create an onboarding plan, then I should be able to include interactive checklists.',
#    'Given a new hire completes a task, when I view their checklist, then it should show the task as completed.'],
#   'priority': 'Medium'},
#  {'id': 12,
#   'persona': 'Department Manager',
#   'feature': 'Interactive Checklists',
#   'user_story': 'As a Department Manager, I want to ensure new hires complete their onboarding tasks, so that they integrate smoothly into the team.',
#   'acceptance_criteria': ["Given I am a Department Manager, when I access a new hire's checklist, then I should see their task completion status.",
#    'Given a new hire is behind on tasks, when I review their checklist, then I should be able to identify incomplete tasks.'],
#   'priority': 'Medium'},
#  {'id': 13,
#   'persona': 'New Employee',
#   'feature': 'Resource Library',
#   'user_story': 'As a New Employee, I want access to a resource library, so that I can find all necessary documents and policies easily.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the resource library, then I should see a list of available documents and policies.',
#    'Given I search for a document, when I enter a keyword, then I should see relevant results.'],
#   'priority': 'High'},
#  {'id': 14,
#   'persona': 'HR Manager',
#   'feature': 'Resource Library',
#   'user_story': 'As an HR Manager, I want to maintain a centralized resource library, so that new hires have easy access to essential documents.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I upload a document to the resource library, then it should be accessible to all new hires.',
#    'Given a document is updated, when I replace it in the library, then the latest version should be available to new hires.'],
#   'priority': 'Medium'},
#  {'id': 15,
#   'persona': 'Department Manager',
#   'feature': 'Resource Library',
#   'user_story': 'As a Department Manager, I want my team to have access to relevant resources, so that they can perform their roles effectively.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I access the resource library, then I should see documents relevant to my department.',
#    'Given a team member requests a document, when I direct them to the library, then they should be able to find it easily.'],
#   'priority': 'Medium'},
#  {'id': 16,
#   'persona': 'New Employee',
#   'feature': 'Virtual Orientation Sessions',
#   'user_story': 'As a New Employee, I want to attend virtual orientation sessions, so that I can learn about the company and ask questions.',
#   'acceptance_criteria': ['Given I am a new employee, when I register for a virtual orientation, then I should receive a confirmation and link to join.',
#    'Given I attend a session, when I have questions, then I should be able to ask them during the Q&A.'],
#   'priority': 'High'},
#  {'id': 17,
#   'persona': 'HR Manager',
#   'feature': 'Virtual Orientation Sessions',
#   'user_story': 'As an HR Manager, I want to organize virtual orientation sessions, so that new hires can learn about the company remotely.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I schedule a virtual orientation, then new hires should receive invitations.',
#    'Given a session is completed, when I review attendance, then I should see a list of participants.'],
#   'priority': 'Medium'},
#  {'id': 18,
#   'persona': 'Department Manager',
#   'feature': 'Virtual Orientation Sessions',
#   'user_story': 'As a Department Manager, I want my new team members to attend orientation sessions, so that they understand the company culture.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check the orientation schedule, then I should see sessions relevant to my team.',
#    'Given a team member attends a session, when I follow up, then they should have a basic understanding of company culture.'],
#   'priority': 'Medium'},
#  {'id': 19,
#   'persona': 'New Employee',
#   'feature': 'Feedback and Surveys',
#   'user_story': 'As a New Employee, I want to provide feedback on the onboarding process, so that it can be improved for future hires.',
#   'acceptance_criteria': ['Given I am a new employee, when I complete a survey, then my feedback should be submitted successfully.',
#    'Given I have feedback, when I access the survey, then I should be able to provide detailed responses.'],
#   'priority': 'Medium'},
#  {'id': 20,
#   'persona': 'HR Manager',
#   'feature': 'Feedback and Surveys',
#   'user_story': 'As an HR Manager, I want to collect feedback from new hires, so that I can improve the onboarding process.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I create a survey, then new hires should receive invitations to participate.',
#    'Given feedback is collected, when I review the results, then I should see aggregated insights.'],
#   'priority': 'Medium'},
#  {'id': 21,
#   'persona': 'Department Manager',
#   'feature': 'Feedback and Surveys',
#   'user_story': 'As a Department Manager, I want to gather feedback from new team members, so that I can address any issues they face.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I access feedback, then I should see responses from my team members.',
#    'Given feedback indicates an issue, when I review it, then I should be able to take corrective action.'],
#   'priority': 'Medium'},
#  {'id': 22,
#   'persona': 'New Employee',
#   'feature': 'Integrations with HR Systems',
#   'user_story': 'As a New Employee, I want the onboarding tool to integrate with HR systems, so that my information is automatically updated.',
#   'acceptance_criteria': ['Given I am a new employee, when I complete my profile, then my information should be synced with HR systems.',
#    'Given I update my details, when I save changes, then they should reflect in the HR system.'],
#   'priority': 'High'},
#  {'id': 23,
#   'persona': 'HR Manager',
#   'feature': 'Integrations with HR Systems',
#   'user_story': 'As an HR Manager, I want the onboarding tool to integrate with HR systems, so that employee data is consistent and up-to-date.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I onboard a new hire, then their data should automatically populate in the HR system.',
#    'Given an update is made in the onboarding tool, when I check the HR system, then it should reflect the changes.'],
#   'priority': 'High'},
#  {'id': 24,
#   'persona': 'Department Manager',
#   'feature': 'Integrations with HR Systems',
#   'user_story': 'As a Department Manager, I want to access updated employee information, so that I can manage my team effectively.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I view team member profiles, then I should see the latest information from the HR system.',
#    'Given a team member updates their details, when I check their profile, then it should reflect the changes.'],
#   'priority': 'Medium'},
#  {'id': 25,
#   'persona': 'New Employee',
#   'feature': 'Role-Specific Training Modules',
#   'user_story': 'As a New Employee, I want access to role-specific training modules, so that I can develop the skills needed for my position.',
#   'acceptance_criteria': ['Given I am a new employee, when I access training modules, then I should see content specific to my role.',
#    'Given I complete a module, when I check my progress, then it should show as completed.'],
#   'priority': 'High'},
#  {'id': 26,
#   'persona': 'HR Manager',
#   'feature': 'Role-Specific Training Modules',
#   'user_story': 'As an HR Manager, I want to provide role-specific training modules, so that new hires receive relevant training.',
#   'acceptance_criteria': ["Given I am an HR Manager, when I assign training modules, then they should be tailored to the new hire's role.",
#    'Given a module is completed, when I review progress, then it should show as completed for the new hire.'],
#   'priority': 'High'},
#  {'id': 27,
#   'persona': 'Department Manager',
#   'feature': 'Role-Specific Training Modules',
#   'user_story': 'As a Department Manager, I want my team members to complete role-specific training, so that they are equipped for their responsibilities.',
#   'acceptance_criteria': ["Given I am a Department Manager, when I review training modules, then I should see content relevant to my team's roles.",
#    'Given a team member completes a module, when I check their progress, then it should show as completed.'],
#   'priority': 'High'},
#  {'id': 28,
#   'persona': 'New Employee',
#   'feature': 'Mentor/Mentee Matching',
#   'user_story': 'As a New Employee, I want to be matched with a mentor, so that I can receive guidance and support during my onboarding.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the mentoring feature, then I should be matched with a mentor.',
#    'Given I have a mentor, when I need guidance, then I should be able to contact them easily.'],
#   'priority': 'Medium'},
#  {'id': 29,
#   'persona': 'HR Manager',
#   'feature': 'Mentor/Mentee Matching',
#   'user_story': 'As an HR Manager, I want to facilitate mentor/mentee matching, so that new hires receive support from experienced employees.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I set up mentor matching, then new hires should be paired with mentors.',
#    'Given a match is made, when I review the pairing, then I should see mentor and mentee details.'],
#   'priority': 'Medium'},
#  {'id': 30,
#   'persona': 'Department Manager',
#   'feature': 'Mentor/Mentee Matching',
#   'user_story': 'As a Department Manager, I want new team members to have mentors, so that they can integrate smoothly into the team.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check mentor assignments, then I should see pairings for my team members.',
#    'Given a team member has a mentor, when I follow up, then they should have received guidance.'],
#   'priority': 'Medium'},
#  {'id': 31,
#   'persona': 'New Employee',
#   'feature': 'Social Integration Tools',
#   'user_story': 'As a New Employee, I want to use social integration tools, so that I can connect with my colleagues and learn about the company culture.',
#   'acceptance_criteria': ['Given I am a new employee, when I access social tools, then I should see options to connect with colleagues.',
#    'Given I join a social group, when I participate, then I should be able to interact with other members.'],
#   'priority': 'Low'},
#  {'id': 32,
#   'persona': 'HR Manager',
#   'feature': 'Social Integration Tools',
#   'user_story': 'As an HR Manager, I want to provide social integration tools, so that new hires can connect with their peers and feel part of the company.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable social tools, then new hires should have access to them.',
#    'Given a new hire uses social tools, when I review engagement, then I should see participation metrics.'],
#   'priority': 'Low'},
#  {'id': 33,
#   'persona': 'Department Manager',
#   'feature': 'Social Integration Tools',
#   'user_story': 'As a Department Manager, I want my team to use social tools, so that they can build relationships and improve teamwork.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I encourage social tool use, then my team should have access to them.',
#    'Given a team member uses social tools, when I check engagement, then I should see their participation.'],
#   'priority': 'Low'},
#  {'id': 34,
#   'persona': 'New Employee',
#   'feature': 'Gamification Elements',
#   'user_story': 'As a New Employee, I want to earn points and badges, so that I stay motivated and engaged during onboarding.',
#   'acceptance_criteria': ['Given I am a new employee, when I complete tasks, then I should earn points and badges.',
#    'Given I earn a badge, when I check my profile, then it should display my achievements.'],
#   'priority': 'Low'},
#  {'id': 35,
#   'persona': 'HR Manager',
#   'feature': 'Gamification Elements',
#   'user_story': 'As an HR Manager, I want to implement gamification, so that new hires remain engaged and motivated throughout the onboarding process.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable gamification, then new hires should see points and badges for tasks.',
#    'Given a new hire earns points, when I review their progress, then it should reflect their achievements.'],
#   'priority': 'Low'},
#  {'id': 36,
#   'persona': 'Department Manager',
#   'feature': 'Gamification Elements',
#   'user_story': 'As a Department Manager, I want my team to engage with gamification, so that they are motivated to complete onboarding tasks.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I promote gamification, then my team should see points and badges for tasks.',
#    'Given a team member earns a badge, when I check their profile, then it should display their achievements.'],
#   'priority': 'Low'},
#  {'id': 37,
#   'persona': 'New Employee',
#   'feature': 'Document e-Signing',
#   'user_story': 'As a New Employee, I want to e-sign documents, so that I can complete onboarding paperwork quickly and efficiently.',
#   'acceptance_criteria': ['Given I am a new employee, when I receive a document, then I should be able to e-sign it.',
#    'Given I e-sign a document, when I submit it, then it should be marked as completed.'],
#   'priority': 'High'},
#  {'id': 38,
#   'persona': 'HR Manager',
#   'feature': 'Document e-Signing',
#   'user_story': 'As an HR Manager, I want new hires to e-sign documents, so that we can streamline the paperwork process.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I send a document for signing, then new hires should be able to e-sign it.',
#    'Given a document is e-signed, when I check the status, then it should show as completed.'],
#   'priority': 'High'},
#  {'id': 39,
#   'persona': 'Department Manager',
#   'feature': 'Document e-Signing',
#   'user_story': 'As a Department Manager, I want my team to complete e-signing of documents, so that we can focus on onboarding activities.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check document status, then I should see if team members have e-signed.',
#    'Given a team member e-signs a document, when I review their onboarding, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 40,
#   'persona': 'New Employee',
#   'feature': 'Mobile Access',
#   'user_story': 'As a New Employee, I want mobile access to the onboarding tool, so that I can complete tasks on the go.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the onboarding tool on my mobile, then I should see a mobile-friendly interface.',
#    'Given I complete a task on mobile, when I check my progress, then it should reflect the completion.'],
#   'priority': 'Medium'},
#  {'id': 41,
#   'persona': 'HR Manager',
#   'feature': 'Mobile Access',
#   'user_story': 'As an HR Manager, I want new hires to have mobile access, so that they can complete onboarding tasks anytime, anywhere.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable mobile access, then new hires should be able to use the tool on their devices.',
#    'Given a new hire completes a task on mobile, when I review their progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 42,
#   'persona': 'Department Manager',
#   'feature': 'Mobile Access',
#   'user_story': 'As a Department Manager, I want my team to have mobile access, so that they can stay on top of onboarding tasks.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check mobile access, then my team should be able to use the tool on their devices.',
#    'Given a team member completes a task on mobile, when I review their progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 43,
#   'persona': 'New Employee',
#   'feature': 'Automated Reminders and Alerts',
#   'user_story': "As a New Employee, I want to receive automated reminders, so that I don't miss any important onboarding tasks.",
#   'acceptance_criteria': ['Given I am a new employee, when a task is due soon, then I should receive a reminder notification.',
#    'Given I complete a task, when I check my notifications, then the reminder should be cleared.'],
#   'priority': 'High'},
#  {'id': 44,
#   'persona': 'HR Manager',
#   'feature': 'Automated Reminders and Alerts',
#   'user_story': 'As an HR Manager, I want to set up automated reminders, so that new hires complete tasks on time.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I configure reminders, then new hires should receive notifications for upcoming tasks.',
#    'Given a task is completed, when I check the reminder status, then it should be marked as done.'],
#   'priority': 'High'},
#  {'id': 45,
#   'persona': 'Department Manager',
#   'feature': 'Automated Reminders and Alerts',
#   'user_story': 'As a Department Manager, I want my team to receive reminders, so that they stay on track with their onboarding.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I review reminder settings, then my team should receive notifications for tasks.',
#    'Given a team member completes a task, when I check their reminders, then it should be cleared.'],
#   'priority': 'High'},
#  {'id': 46,
#   'persona': 'New Employee',
#   'feature': 'Multi-Language Support',
#   'user_story': 'As a New Employee, I want onboarding content in my preferred language, so that I can understand it better.',
#   'acceptance_criteria': ['Given I am a new employee, when I select my preferred language, then the onboarding content should be displayed in that language.',
#    'Given I switch languages, when I navigate the tool, then all content should update to the selected language.'],
#   'priority': 'Medium'},
#  {'id': 47,
#   'persona': 'HR Manager',
#   'feature': 'Multi-Language Support',
#   'user_story': 'As an HR Manager, I want to provide multi-language support, so that all new hires can understand the onboarding content.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable multi-language support, then new hires should be able to select their preferred language.',
#    'Given a language is selected, when I review content, then it should be available in that language.'],
#   'priority': 'Medium'},
#  {'id': 48,
#   'persona': 'Department Manager',
#   'feature': 'Multi-Language Support',
#   'user_story': 'As a Department Manager, I want my team to access content in their preferred language, so that they can understand it fully.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check language settings, then my team should be able to select their preferred language.',
#    'Given a team member selects a language, when I review their content, then it should be in that language.'],
#   'priority': 'Medium'},
#  {'id': 49,
#   'persona': 'New Employee',
#   'feature': 'Video Introductions',
#   'user_story': 'As a New Employee, I want to watch video introductions from team members, so that I can get to know them better.',
#   'acceptance_criteria': ['Given I am a new employee, when I access video introductions, then I should see videos from team members.',
#    'Given I watch a video, when I finish, then I should have a better understanding of the team member.'],
#   'priority': 'Low'},
#  {'id': 50,
#   'persona': 'HR Manager',
#   'feature': 'Video Introductions',
#   'user_story': 'As an HR Manager, I want to provide video introductions, so that new hires can familiarize themselves with the team.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I upload a video introduction, then it should be available to new hires.',
#    'Given a new hire watches a video, when I review engagement, then I should see view metrics.'],
#   'priority': 'Low'},
#  {'id': 51,
#   'persona': 'Department Manager',
#   'feature': 'Video Introductions',
#   'user_story': 'As a Department Manager, I want my team to create video introductions, so that new hires can get to know them.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I request video introductions, then my team should be able to upload them.',
#    'Given a new hire watches a video, when I check engagement, then I should see view metrics.'],
#   'priority': 'Low'},
#  {'id': 52,
#   'persona': 'New Employee',
#   'feature': 'Knowledge Check Quizzes',
#   'user_story': 'As a New Employee, I want to take quizzes, so that I can assess my understanding of the onboarding material.',
#   'acceptance_criteria': ['Given I am a new employee, when I complete a module, then I should be prompted to take a quiz.',
#    'Given I take a quiz, when I finish, then I should see my score and feedback.'],
#   'priority': 'Medium'},
#  {'id': 53,
#   'persona': 'HR Manager',
#   'feature': 'Knowledge Check Quizzes',
#   'user_story': 'As an HR Manager, I want to provide quizzes, so that new hires can test their understanding of the onboarding content.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I create a quiz, then it should be available to new hires after completing a module.',
#    'Given a new hire takes a quiz, when I review results, then I should see their scores and feedback.'],
#   'priority': 'Medium'},
#  {'id': 54,
#   'persona': 'Department Manager',
#   'feature': 'Knowledge Check Quizzes',
#   'user_story': 'As a Department Manager, I want my team to take quizzes, so that they can confirm their understanding of the material.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check quiz availability, then my team should be able to take them after modules.',
#    'Given a team member takes a quiz, when I review their results, then I should see their scores and feedback.'],
#   'priority': 'Medium'},
#  {'id': 55,
#   'persona': 'New Employee',
#   'feature': 'Virtual Reality Tours',
#   'user_story': 'As a New Employee, I want to take virtual reality tours, so that I can familiarize myself with the office environment.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the VR tour feature, then I should be able to start a virtual tour.',
#    'Given I complete a tour, when I finish, then I should have a better understanding of the office layout.'],
#   'priority': 'Low'},
#  {'id': 56,
#   'persona': 'HR Manager',
#   'feature': 'Virtual Reality Tours',
#   'user_story': 'As an HR Manager, I want to offer virtual reality tours, so that new hires can explore the office remotely.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable VR tours, then new hires should have access to them.',
#    'Given a new hire completes a tour, when I review engagement, then I should see participation metrics.'],
#   'priority': 'Low'},
#  {'id': 57,
#   'persona': 'Department Manager',
#   'feature': 'Virtual Reality Tours',
#   'user_story': 'As a Department Manager, I want my team to take VR tours, so that they can become familiar with the office environment.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check VR tour availability, then my team should have access to them.',
#    'Given a team member completes a tour, when I review their feedback, then they should have a better understanding of the office layout.'],
#   'priority': 'Low'},
#  {'id': 58,
#   'persona': 'New Employee',
#   'feature': 'Customizable Templates',
#   'user_story': 'As a New Employee, I want to use customizable templates, so that I can complete onboarding tasks more efficiently.',
#   'acceptance_criteria': ['Given I am a new employee, when I access templates, then I should see options to customize them for my tasks.',
#    'Given I customize a template, when I save it, then it should be available for future use.'],
#   'priority': 'Low'},
#  {'id': 59,
#   'persona': 'HR Manager',
#   'feature': 'Customizable Templates',
#   'user_story': 'As an HR Manager, I want to provide customizable templates, so that new hires can complete tasks more efficiently.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I create a template, then it should be customizable by new hires.',
#    'Given a template is customized, when I review it, then it should reflect the changes made by the new hire.'],
#   'priority': 'Low'},
#  {'id': 60,
#   'persona': 'Department Manager',
#   'feature': 'Customizable Templates',
#   'user_story': 'As a Department Manager, I want my team to use customizable templates, so that they can complete tasks more efficiently.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check template availability, then my team should be able to customize them.',
#    'Given a team member customizes a template, when I review it, then it should reflect their changes.'],
#   'priority': 'Low'},
#  {'id': 61,
#   'persona': 'New Employee',
#   'feature': 'Peer Networking Tools',
#   'user_story': 'As a New Employee, I want to use peer networking tools, so that I can connect with other new hires and build relationships.',
#   'acceptance_criteria': ['Given I am a new employee, when I access networking tools, then I should see options to connect with peers.',
#    'Given I join a networking group, when I participate, then I should be able to interact with other new hires.'],
#   'priority': 'Low'},
#  {'id': 62,
#   'persona': 'HR Manager',
#   'feature': 'Peer Networking Tools',
#   'user_story': 'As an HR Manager, I want to provide peer networking tools, so that new hires can connect and build relationships.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable networking tools, then new hires should have access to them.',
#    'Given a new hire uses networking tools, when I review engagement, then I should see participation metrics.'],
#   'priority': 'Low'},
#  {'id': 63,
#   'persona': 'Department Manager',
#   'feature': 'Peer Networking Tools',
#   'user_story': 'As a Department Manager, I want my team to use networking tools, so that they can connect with peers and build relationships.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I encourage networking tool use, then my team should have access to them.',
#    'Given a team member uses networking tools, when I check engagement, then I should see their participation.'],
#   'priority': 'Low'},
#  {'id': 64,
#   'persona': 'New Employee',
#   'feature': 'Onboarding Analytics and Reporting',
#   'user_story': "As a New Employee, I want to see analytics on my onboarding progress, so that I can understand how I'm doing.",
#   'acceptance_criteria': ['Given I am a new employee, when I access analytics, then I should see data on my onboarding progress.',
#    'Given I complete a task, when I check analytics, then it should reflect the updated progress.'],
#   'priority': 'Medium'},
#  {'id': 65,
#   'persona': 'HR Manager',
#   'feature': 'Onboarding Analytics and Reporting',
#   'user_story': 'As an HR Manager, I want to access onboarding analytics, so that I can evaluate the effectiveness of the onboarding process.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I access analytics, then I should see data on onboarding effectiveness.',
#    'Given a new hire completes a task, when I review analytics, then it should reflect the updated progress.'],
#   'priority': 'High'},
#  {'id': 66,
#   'persona': 'Department Manager',
#   'feature': 'Onboarding Analytics and Reporting',
#   'user_story': "As a Department Manager, I want to see analytics on my team's onboarding, so that I can identify areas for improvement.",
#   'acceptance_criteria': ["Given I am a Department Manager, when I access analytics, then I should see data on my team's onboarding progress.",
#    'Given a team member completes a task, when I review analytics, then it should reflect the updated progress.'],
#   'priority': 'High'},
#  {'id': 67,
#   'persona': 'New Employee',
#   'feature': 'Self-Service FAQs and Chatbot',
#   'user_story': 'As a New Employee, I want to use a chatbot for common queries, so that I can get quick answers without waiting.',
#   'acceptance_criteria': ['Given I am a new employee, when I ask a question to the chatbot, then I should receive an immediate response.',
#    'Given my query is not resolved, when I request further assistance, then I should be directed to additional resources.'],
#   'priority': 'Medium'},
#  {'id': 68,
#   'persona': 'HR Manager',
#   'feature': 'Self-Service FAQs and Chatbot',
#   'user_story': 'As an HR Manager, I want to provide a chatbot for common queries, so that new hires can get quick answers.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I update FAQs, then the chatbot should provide accurate responses.',
#    'Given a new hire uses the chatbot, when I review engagement, then I should see query metrics.'],
#   'priority': 'Medium'},
#  {'id': 69,
#   'persona': 'Department Manager',
#   'feature': 'Self-Service FAQs and Chatbot',
#   'user_story': 'As a Department Manager, I want my team to use a chatbot for queries, so that they can get quick answers and stay focused.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check chatbot availability, then my team should have access to it.',
#    'Given a team member uses the chatbot, when I review engagement, then I should see query metrics.'],
#   'priority': 'Medium'},
#  {'id': 70,
#   'persona': 'New Employee',
#   'feature': 'Task Automation',
#   'user_story': 'As a New Employee, I want administrative tasks to be automated, so that I can focus on learning and integration.',
#   'acceptance_criteria': ['Given I am a new employee, when I complete a task, then any related administrative tasks should be automated.',
#    'Given an administrative task is automated, when I check my task list, then it should be marked as completed.'],
#   'priority': 'High'},
#  {'id': 71,
#   'persona': 'HR Manager',
#   'feature': 'Task Automation',
#   'user_story': 'As an HR Manager, I want to automate administrative tasks, so that the onboarding process is more efficient.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I configure task automation, then related tasks should be automated for new hires.',
#    'Given a task is automated, when I review the process, then it should show as completed without manual intervention.'],
#   'priority': 'High'},
#  {'id': 72,
#   'persona': 'Department Manager',
#   'feature': 'Task Automation',
#   'user_story': 'As a Department Manager, I want administrative tasks to be automated, so that my team can focus on their roles.',
#   'acceptance_criteria': ["Given I am a Department Manager, when I check task automation, then my team's administrative tasks should be automated.",
#    'Given a task is automated, when I review the process, then it should show as completed without manual intervention.'],
#   'priority': 'High'},
#  {'id': 73,
#   'persona': 'New Employee',
#   'feature': 'Cultural Integration Modules',
#   'user_story': "As a New Employee, I want to complete cultural integration modules, so that I understand the company's values and mission.",
#   'acceptance_criteria': ['Given I am a new employee, when I access cultural modules, then I should see content on company values and mission.',
#    'Given I complete a module, when I check my progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 74,
#   'persona': 'HR Manager',
#   'feature': 'Cultural Integration Modules',
#   'user_story': "As an HR Manager, I want to provide cultural integration modules, so that new hires understand the company's values and mission.",
#   'acceptance_criteria': ['Given I am an HR Manager, when I create a cultural module, then it should be available to new hires.',
#    'Given a new hire completes a module, when I review progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 75,
#   'persona': 'Department Manager',
#   'feature': 'Cultural Integration Modules',
#   'user_story': "As a Department Manager, I want my team to complete cultural modules, so that they understand the company's values and mission.",
#   'acceptance_criteria': ['Given I am a Department Manager, when I check module availability, then my team should have access to cultural content.',
#    'Given a team member completes a module, when I review their progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 76,
#   'persona': 'New Employee',
#   'feature': 'Time Management Tools',
#   'user_story': 'As a New Employee, I want to use time management tools, so that I can schedule my onboarding activities effectively.',
#   'acceptance_criteria': ['Given I am a new employee, when I access time management tools, then I should see options to schedule activities.',
#    'Given I schedule an activity, when I check my calendar, then it should reflect the scheduled time.'],
#   'priority': 'Low'},
#  {'id': 77,
#   'persona': 'HR Manager',
#   'feature': 'Time Management Tools',
#   'user_story': 'As an HR Manager, I want to provide time management tools, so that new hires can schedule their onboarding activities.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable time management tools, then new hires should have access to them.',
#    'Given a new hire schedules an activity, when I review their calendar, then it should reflect the scheduled time.'],
#   'priority': 'Low'},
#  {'id': 78,
#   'persona': 'Department Manager',
#   'feature': 'Time Management Tools',
#   'user_story': 'As a Department Manager, I want my team to use time management tools, so that they can schedule their activities effectively.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check tool availability, then my team should have access to time management tools.',
#    'Given a team member schedules an activity, when I review their calendar, then it should reflect the scheduled time.'],
#   'priority': 'Low'},
#  {'id': 79,
#   'persona': 'New Employee',
#   'feature': 'Manager Dashboards',
#   'user_story': 'As a New Employee, I want my manager to have access to a dashboard, so that they can track my onboarding progress.',
#   'acceptance_criteria': ['Given I am a new employee, when my manager accesses the dashboard, then they should see my onboarding progress.',
#    'Given I complete a task, when my manager checks the dashboard, then it should reflect the updated progress.'],
#   'priority': 'High'},
#  {'id': 80,
#   'persona': 'HR Manager',
#   'feature': 'Manager Dashboards',
#   'user_story': "As an HR Manager, I want managers to have access to dashboards, so that they can track their team's onboarding progress.",
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable manager dashboards, then managers should have access to them.',
#    'Given a team member completes a task, when a manager checks the dashboard, then it should reflect the updated progress.'],
#   'priority': 'High'},
#  {'id': 81,
#   'persona': 'Department Manager',
#   'feature': 'Manager Dashboards',
#   'user_story': "As a Department Manager, I want access to a dashboard, so that I can track my team's onboarding progress.",
#   'acceptance_criteria': ["Given I am a Department Manager, when I access the dashboard, then I should see my team's onboarding progress.",
#    'Given a team member completes a task, when I check the dashboard, then it should reflect the updated progress.'],
#   'priority': 'High'},
#  {'id': 82,
#   'persona': 'New Employee',
#   'feature': 'Access to Company News and Updates',
#   'user_story': 'As a New Employee, I want access to company news and updates, so that I stay informed about the organization.',
#   'acceptance_criteria': ['Given I am a new employee, when I access the news section, then I should see the latest company updates.',
#    'Given a new update is posted, when I check the news section, then it should be visible.'],
#   'priority': 'Low'},
#  {'id': 83,
#   'persona': 'HR Manager',
#   'feature': 'Access to Company News and Updates',
#   'user_story': 'As an HR Manager, I want new hires to have access to company news, so that they stay informed about the organization.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I post a news update, then it should be visible to new hires.',
#    'Given a new hire accesses the news section, when I review engagement, then I should see view metrics.'],
#   'priority': 'Low'},
#  {'id': 84,
#   'persona': 'Department Manager',
#   'feature': 'Access to Company News and Updates',
#   'user_story': 'As a Department Manager, I want my team to have access to company news, so that they stay informed about the organization.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check news availability, then my team should have access to the latest updates.',
#    'Given a team member accesses the news section, when I review engagement, then I should see view metrics.'],
#   'priority': 'Low'},
#  {'id': 85,
#   'persona': 'New Employee',
#   'feature': 'Scenario-Based Learning',
#   'user_story': 'As a New Employee, I want to engage in scenario-based learning, so that I can practice real-world situations.',
#   'acceptance_criteria': ['Given I am a new employee, when I access scenario-based learning, then I should see simulations relevant to my role.',
#    'Given I complete a simulation, when I check my progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 86,
#   'persona': 'HR Manager',
#   'feature': 'Scenario-Based Learning',
#   'user_story': 'As an HR Manager, I want to provide scenario-based learning, so that new hires can practice real-world situations.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I create a scenario, then it should be available to new hires.',
#    'Given a new hire completes a simulation, when I review progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 87,
#   'persona': 'Department Manager',
#   'feature': 'Scenario-Based Learning',
#   'user_story': 'As a Department Manager, I want my team to engage in scenario-based learning, so that they can practice real-world situations.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I check scenario availability, then my team should have access to simulations.',
#    'Given a team member completes a simulation, when I review their progress, then it should show as completed.'],
#   'priority': 'Medium'},
#  {'id': 88,
#   'persona': 'New Employee',
#   'feature': 'Feedback Loop with Managers',
#   'user_story': 'As a New Employee, I want a feedback loop with my manager, so that I can receive guidance and support during onboarding.',
#   'acceptance_criteria': ['Given I am a new employee, when I provide feedback, then my manager should be notified.',
#    'Given my manager responds, when I check my feedback, then I should see their response.'],
#   'priority': 'High'},
#  {'id': 89,
#   'persona': 'HR Manager',
#   'feature': 'Feedback Loop with Managers',
#   'user_story': 'As an HR Manager, I want to facilitate a feedback loop between new hires and managers, so that they can receive guidance and support.',
#   'acceptance_criteria': ['Given I am an HR Manager, when I enable feedback loops, then new hires should be able to communicate with their managers.',
#    'Given a new hire provides feedback, when I review engagement, then I should see communication metrics.'],
#   'priority': 'High'},
#  {'id': 90,
#   'persona': 'Department Manager',
#   'feature': 'Feedback Loop with Managers',
#   'user_story': 'As a Department Manager, I want a feedback loop with my team, so that I can provide guidance and support during onboarding.',
#   'acceptance_criteria': ['Given I am a Department Manager, when I receive feedback, then I should be able to respond to my team members.',
#    'Given a team member provides feedback, when I review it, then I should see their comments and respond.'],
#   'priority': 'High'}]

# %% [markdown]
# ### Challenge 3 (Advanced): Programmatic Validation and Artifact Creation
#
# **Task:** Now for the highest-value step. Instead of just looking at the JSON, we will programmatically validate it and save it as a formal project artifact. This ensures reliability and prepares the requirements for automated use in later stages of the SDLC.
#
# **Instructions:**
# 1. Complete the `validate_and_save_stories` function below.
# 2. The function should iterate through the list of stories.
# 3. For each story, it must validate that the required keys are present and that the acceptance criteria list is not empty.
# 4. If all stories are valid, it should save the data to `artifacts/day1_user_stories.json`.
#
# **Expected Quality:** A robust script that guarantees the integrity of our requirements artifact. The final output is a validated `day1_user_stories.json` file in the `artifacts` directory, ready to be used as a reliable input for Day 2.

# %%
def validate_and_save_stories(stories_data):
    """Validates the structure of the user stories data and saves it if valid."""
    if not isinstance(stories_data, list) or not stories_data:
        print("Validation Failed: Data is not a non-empty list.")
        return

    required_keys = ['id', 'persona', 'user_story', 'acceptance_criteria']
    all_stories_valid = True

    # Validate each story
    for story in stories_data:
        # Check if all required keys exist
        missing_keys = [key for key in required_keys if key not in story]
        if missing_keys:
            print(f"Validation Failed: Story {story.get('id', 'unknown')} is missing keys: {missing_keys}")
            all_stories_valid = False
            continue
        
        # Check if acceptance criteria is a non-empty list
        if not isinstance(story['acceptance_criteria'], list) or not story['acceptance_criteria']:
            print(f"Validation Failed: Story {story['id']} has invalid or empty acceptance criteria")
            all_stories_valid = False
            continue

    if all_stories_valid:
        print("\nAll user stories passed validation.")
        artifact_path = "artifacts/day1_user_stories.json"
        
        # Convert to JSON string and save
        json_str = json.dumps(stories_data, indent=2)
        save_artifact(json_str, artifact_path)
        print(f"User stories saved to {artifact_path}")
    else:
        print("\nValidation failed. Artifact not saved.")

# Run the validation on the JSON data from the previous step
if 'user_stories_json' in locals() and user_stories_json:
    validate_and_save_stories(user_stories_json)
else:
    print("Skipping validation as user_stories_json is empty or not defined.")
# Out:
# All user stories passed validation.
# ✅ Successfully saved artifact to: artifacts/day1_user_stories.json
# User stories saved to artifacts/day1_user_stories.json

# %% [markdown]
# ## Lab Conclusion
#
# Congratulations! You have completed the first lab. You started with a vague, one-sentence problem and finished with a structured, validated, machine-readable requirements artifact. This is the critical first step in an AI-assisted software development lifecycle. The `day1_user_stories.json` file you created will be the direct input for our next lab, where we will generate a formal Product Requirements Document (PRD).
#
# > **Key Takeaway:** The single most important skill demonstrated in this lab is turning unstructured ideas into structured, machine-readable data (JSON). This transformation is what enables automation and integration with other tools later in the SDLC.
