# %% [markdown]
# # Day 1 - Lab 2: Generating a Product Requirements Document (PRD)
#
# **Objective:** Use the structured `day1_user_stories.json` artifact from the previous lab to generate a formal, comprehensive Product Requirements Document (PRD) in markdown format.
#
# **Estimated Time:** 60 minutes
#
# **Introduction:**
# With a validated set of user stories, we can now create a higher-level planning document: the PRD. A PRD serves as the source of truth for the product team, outlining the project's purpose, features, and requirements. In this lab, you will use an LLM to synthesize the detailed user stories into this formal document.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# This initial block sets up our environment. It adds the project's root directory to the Python path, allowing us to import our custom `utils.py` script. We then initialize the connection to our Large Language Model (LLM) and load the JSON artifact from the previous lab.
#
# **Model Selection:**
# You can change the `model_name` parameter in the `setup_llm_client()` function to any of the models listed in `utils.py`, such as `"gemini-2.5-flash"` or `"meta-llama/Llama-3.3-70B-Instruct"`.
#
# **Helper Functions Used:**
# - `setup_llm_client()`: To configure the API client.
# - `get_completion()`: To send prompts to the LLM.
# - `load_artifact()`: To read the user stories JSON file and the PRD template.
# - `save_artifact()`: To save our generated PRD and Pydantic model.

# %%
import sys
import os
import json

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Assumes the notebook is in 'labs/Day_01_.../'
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    # Fallback for different execution environments
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact, load_artifact

# Initialize the LLM client. You can change the model here.
client, model_name, api_provider = setup_llm_client(model_name="gpt-4o")

# Load the artifact from Lab 1
artifacts_path = os.getenv("ARTIFACTS_PATH", "../../artifacts")
user_stories_str = load_artifact("artifacts/day1_user_stories.json")
if user_stories_str:
    user_stories_data = json.loads(user_stories_str)
else:
    user_stories_data = []
# Out:
# ✅ LLM Client configured: Using 'openai' with model 'gpt-4o'

# %% [markdown]
# ## Step 2: The Challenges

# %% [markdown]
# ### Challenge 1 (Foundational): Generating a Simple PRD
#
# **Task:** Use the loaded user stories to generate a simple PRD.
#
# **Instructions:**
# 1. Create a prompt that instructs the LLM to act as a Product Manager.
# 2. Provide the `user_stories_data` as context.
# 3. Ask the LLM to generate a PRD with three sections: "Introduction", "User Personas", and "Features / User Stories".
#
# **Expected Quality:** A clean markdown document that correctly summarizes the provided user stories into the requested sections.

# %%
# TODO: Write a prompt to generate a simple PRD.
simple_prd_prompt = f"""
You are a Product Manager tasked with creating a Product Requirements Document (PRD) for a new hire onboarding tool.

Use the following JSON data containing user stories as your primary source of information:
<user_stories>
{user_stories_str}
</user_stories>

Your task:
- Write a PRD in markdown format.
- Ensure the document is clear, concise, and professional.

The PRD must include the following sections:

1. **Introduction:**
   - Provide a brief overview of the project's purpose, goals, and the problem it aims to solve.
   - Highlight the importance of the onboarding tool for the organization.

2. **User Personas:**
   - Summarize the key user personas derived from the user stories.
   - Include their roles, goals, and how they interact with the onboarding tool.

3. **Features / User Stories:**
   - List the features and user stories from the `user_stories_data` variable.
   - For each user story, include:
     - The persona it addresses.
     - The feature it relates to.
     - The user story in the format: "As a [persona], I want to [do something], so that [benefit]."
     - The acceptance criteria in Gherkin format (Given/When/Then).

Output the PRD in markdown format, ensuring proper section headers and formatting.
"""

print("--- Generating Simple PRD ---")
if user_stories_data:
    simple_prd_output = get_completion(simple_prd_prompt, client, model_name, api_provider)
    print(simple_prd_output)
else:
    print("Skipping PRD generation because user stories are missing.")
# Out:
# --- Generating Simple PRD ---
# ```markdown
# # Product Requirements Document (PRD)
#
# ## Introduction
# The New Hire Onboarding Tool is designed to streamline and enhance the onboarding process for new employees, HR managers, and department managers. This tool aims to solve the common challenges of onboarding by providing a centralized platform that offers personalized learning paths, progress tracking, compliance training, and various other features essential for an effective onboarding experience. The onboarding tool is crucial for the organization as it facilitates a smooth transition for new hires, ensures compliance with company policies, and fosters an engaging and supportive work environment.
#
# ## User Personas
#
# ### New Employee
# - **Role:** Newly hired staff member.
# - **Goals:** Acclimate quickly to the company, complete onboarding tasks efficiently, and understand their role and the company's culture.
# - **Interaction:** Uses the tool to access learning paths, track progress, complete compliance training, and interact with mentors and peers.
#
# ### HR Manager
# - **Role:** Oversees the onboarding process and ensures compliance.
# - **Goals:** Customize onboarding experiences, monitor new hire progress, and maintain compliance with regulations.
# - **Interaction:** Uses the tool to create onboarding plans, track employee progress, and gather feedback for continuous improvement.
#
# ### Department Manager
# - **Role:** Manages a specific department and oversees team integration.
# - **Goals:** Ensure team members complete onboarding tasks relevant to their roles and provide support where needed.
# - **Interaction:** Uses the tool to track team progress, verify compliance, and facilitate mentoring relationships.
#
# ## Features / User Stories
#
# ### Personalized Learning Paths
# - **User Stories:**
#   1. **Persona:** New Employee
#      **Feature:** Personalized Learning Paths
#      **User Story:** As a New Employee, I want to have a personalized learning path, so that I can focus on the most relevant information for my role.
#      **Acceptance Criteria:**
#      - Given I am a new employee, when I log into the onboarding tool, then I should see a personalized learning path based on my role.
#      - Given I have completed a module, when I check my progress, then it should reflect the completion in my learning path.
#
#   2. **Persona:** HR Manager
#      **Feature:** Personalized Learning Paths
#      **User Story:** As an HR Manager, I want to customize learning paths for new hires, so that each employee receives training relevant to their role.
#      **Acceptance Criteria:**
#      - Given I am an HR Manager, when I create a new onboarding plan, then I should be able to customize learning paths based on roles.
#      - Given a new hire is assigned a role, when they start onboarding, then they should see a learning path tailored to their role.
#
#   3. **Persona:** Department Manager
#      **Feature:** Personalized Learning Paths
#      **User Story:** As a Department Manager, I want to ensure new hires have role-specific learning paths, so that they acquire the necessary skills quickly.
#      **Acceptance Criteria:**
#      - Given I am a Department Manager, when I review a new hire's onboarding progress, then I should see their role-specific learning path.
#      - Given a new hire completes a module, when I check their progress, then it should show updated completion status.
#
# ### Progress Tracking Dashboard
# - **User Stories:**
#   4. **Persona:** New Employee
#      **Feature:** Progress Tracking Dashboard
#      **User Story:** As a New Employee, I want to track my onboarding progress, so that I know what tasks I have completed and what is pending.
#      **Acceptance Criteria:**
#      - Given I am a new employee, when I access the onboarding tool, then I should see a dashboard displaying my progress.
#      - Given I complete a task, when I refresh the dashboard, then it should reflect the updated progress.
#
#   5. **Persona:** HR Manager
#      **Feature:** Progress Tracking Dashboard
#      **User Story:** As an HR Manager, I want to monitor the progress of new hires, so that I can ensure they are on track with their onboarding.
#      **Acceptance Criteria:**
#      - Given I am an HR Manager, when I view the onboarding dashboard, then I should see the progress of all new hires.
#      - Given a new hire completes a task, when I check their progress, then it should show the updated status.
#
#   6. **Persona:** Department Manager
#      **Feature:** Progress Tracking Dashboard
#      **User Story:** As a Department Manager, I want to track the onboarding progress of my team members, so that I can provide support where needed.
#      **Acceptance Criteria:**
#      - Given I am a Department Manager, when I access the dashboard, then I should see the progress of new hires in my department.
#      - Given a new hire is behind schedule, when I view their progress, then I should be able to identify areas where they need support.
#
# ### Compliance Module
# - **User Stories:**
#   7. **Persona:** New Employee
#      **Feature:** Compliance Module
#      **User Story:** As a New Employee, I want to complete compliance training, so that I adhere to company policies.
#      **Acceptance Criteria:**
#      - Given I am a new employee, when I access the compliance module, then I should see a list of required training sessions.
#      - Given I complete a compliance session, when I check my status, then it should show as completed.
#
#   8. **Persona:** HR Manager
#      **Feature:** Compliance Module
#      **User Story:** As an HR Manager, I want to ensure all new hires complete compliance training, so that the organization remains compliant with regulations.
#      **Acceptance Criteria:**
#      - Given I am an HR Manager, when I view the compliance dashboard, then I should see the completion status of all new hires.
#      - Given a new hire has not completed a session, when I check their compliance status, then it should show as pending.
#
#   9. **Persona:** Department Manager
#      **Feature:** Compliance Module
#      **User Story:** As a Department Manager, I want to verify that my team members have completed compliance training, so that we adhere to company standards.
#      **Acceptance Criteria:**
#      - Given I am a Department Manager, when I access the compliance module, then I should see the training status of my team members.
#      - Given a team member completes a session, when I check their compliance status, then it should show as completed.
#
# ### Interactive Checklists
# - **User Stories:**
#   10. **Persona:** New Employee
#       **Feature:** Interactive Checklists
#       **User Story:** As a New Employee, I want to follow an interactive checklist, so that I complete all onboarding tasks on time.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access the onboarding tool, then I should see an interactive checklist of tasks.
#       - Given I complete a task, when I check the checklist, then it should show the task as completed.
#
#   11. **Persona:** HR Manager
#       **Feature:** Interactive Checklists
#       **User Story:** As an HR Manager, I want to provide new hires with interactive checklists, so that they can complete onboarding tasks systematically.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I create an onboarding plan, then I should be able to include interactive checklists.
#       - Given a new hire completes a task, when I view their checklist, then it should show the task as completed.
#
#   12. **Persona:** Department Manager
#       **Feature:** Interactive Checklists
#       **User Story:** As a Department Manager, I want to ensure new hires complete their onboarding tasks, so that they integrate smoothly into the team.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I access a new hire's checklist, then I should see their task completion status.
#       - Given a new hire is behind on tasks, when I review their checklist, then I should be able to identify incomplete tasks.
#
# ### Resource Library
# - **User Stories:**
#   13. **Persona:** New Employee
#       **Feature:** Resource Library
#       **User Story:** As a New Employee, I want access to a resource library, so that I can find all necessary documents and policies easily.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access the resource library, then I should see a list of available documents and policies.
#       - Given I search for a document, when I enter a keyword, then I should see relevant results.
#
#   14. **Persona:** HR Manager
#       **Feature:** Resource Library
#       **User Story:** As an HR Manager, I want to maintain a centralized resource library, so that new hires have easy access to essential documents.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I upload a document to the resource library, then it should be accessible to all new hires.
#       - Given a document is updated, when I replace it in the library, then the latest version should be available to new hires.
#
#   15. **Persona:** Department Manager
#       **Feature:** Resource Library
#       **User Story:** As a Department Manager, I want my team to have access to relevant resources, so that they can perform their roles effectively.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I access the resource library, then I should see documents relevant to my department.
#       - Given a team member requests a document, when I direct them to the library, then they should be able to find it easily.
#
# ### Virtual Orientation Sessions
# - **User Stories:**
#   16. **Persona:** New Employee
#       **Feature:** Virtual Orientation Sessions
#       **User Story:** As a New Employee, I want to attend virtual orientation sessions, so that I can learn about the company and ask questions.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I register for a virtual orientation, then I should receive a confirmation and link to join.
#       - Given I attend a session, when I have questions, then I should be able to ask them during the Q&A.
#
#   17. **Persona:** HR Manager
#       **Feature:** Virtual Orientation Sessions
#       **User Story:** As an HR Manager, I want to organize virtual orientation sessions, so that new hires can learn about the company remotely.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I schedule a virtual orientation, then new hires should receive invitations.
#       - Given a session is completed, when I review attendance, then I should see a list of participants.
#
#   18. **Persona:** Department Manager
#       **Feature:** Virtual Orientation Sessions
#       **User Story:** As a Department Manager, I want my new team members to attend orientation sessions, so that they understand the company culture.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check the orientation schedule, then I should see sessions relevant to my team.
#       - Given a team member attends a session, when I follow up, then they should have a basic understanding of company culture.
#
# ### Feedback and Surveys
# - **User Stories:**
#   19. **Persona:** New Employee
#       **Feature:** Feedback and Surveys
#       **User Story:** As a New Employee, I want to provide feedback on the onboarding process, so that it can be improved for future hires.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I complete a survey, then my feedback should be submitted successfully.
#       - Given I have feedback, when I access the survey, then I should be able to provide detailed responses.
#
#   20. **Persona:** HR Manager
#       **Feature:** Feedback and Surveys
#       **User Story:** As an HR Manager, I want to collect feedback from new hires, so that I can improve the onboarding process.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I create a survey, then new hires should receive invitations to participate.
#       - Given feedback is collected, when I review the results, then I should see aggregated insights.
#
#   21. **Persona:** Department Manager
#       **Feature:** Feedback and Surveys
#       **User Story:** As a Department Manager, I want to gather feedback from new team members, so that I can address any issues they face.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I access feedback, then I should see responses from my team members.
#       - Given feedback indicates an issue, when I review it, then I should be able to take corrective action.
#
# ### Integrations with HR Systems
# - **User Stories:**
#   22. **Persona:** New Employee
#       **Feature:** Integrations with HR Systems
#       **User Story:** As a New Employee, I want the onboarding tool to integrate with HR systems, so that my information is automatically updated.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I complete my profile, then my information should be synced with HR systems.
#       - Given I update my details, when I save changes, then they should reflect in the HR system.
#
#   23. **Persona:** HR Manager
#       **Feature:** Integrations with HR Systems
#       **User Story:** As an HR Manager, I want the onboarding tool to integrate with HR systems, so that employee data is consistent and up-to-date.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I onboard a new hire, then their data should automatically populate in the HR system.
#       - Given an update is made in the onboarding tool, when I check the HR system, then it should reflect the changes.
#
#   24. **Persona:** Department Manager
#       **Feature:** Integrations with HR Systems
#       **User Story:** As a Department Manager, I want to access updated employee information, so that I can manage my team effectively.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I view team member profiles, then I should see the latest information from the HR system.
#       - Given a team member updates their details, when I check their profile, then it should reflect the changes.
#
# ### Role-Specific Training Modules
# - **User Stories:**
#   25. **Persona:** New Employee
#       **Feature:** Role-Specific Training Modules
#       **User Story:** As a New Employee, I want access to role-specific training modules, so that I can develop the skills needed for my position.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access training modules, then I should see content specific to my role.
#       - Given I complete a module, when I check my progress, then it should show as completed.
#
#   26. **Persona:** HR Manager
#       **Feature:** Role-Specific Training Modules
#       **User Story:** As an HR Manager, I want to provide role-specific training modules, so that new hires receive relevant training.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I assign training modules, then they should be tailored to the new hire's role.
#       - Given a module is completed, when I review progress, then it should show as completed for the new hire.
#
#   27. **Persona:** Department Manager
#       **Feature:** Role-Specific Training Modules
#       **User Story:** As a Department Manager, I want my team members to complete role-specific training, so that they are equipped for their responsibilities.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I review training modules, then I should see content relevant to my team's roles.
#       - Given a team member completes a module, when I check their progress, then it should show as completed.
#
# ### Mentor/Mentee Matching
# - **User Stories:**
#   28. **Persona:** New Employee
#       **Feature:** Mentor/Mentee Matching
#       **User Story:** As a New Employee, I want to be matched with a mentor, so that I can receive guidance and support during my onboarding.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access the mentoring feature, then I should be matched with a mentor.
#       - Given I have a mentor, when I need guidance, then I should be able to contact them easily.
#
#   29. **Persona:** HR Manager
#       **Feature:** Mentor/Mentee Matching
#       **User Story:** As an HR Manager, I want to facilitate mentor/mentee matching, so that new hires receive support from experienced employees.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I set up mentor matching, then new hires should be paired with mentors.
#       - Given a match is made, when I review the pairing, then I should see mentor and mentee details.
#
#   30. **Persona:** Department Manager
#       **Feature:** Mentor/Mentee Matching
#       **User Story:** As a Department Manager, I want new team members to have mentors, so that they can integrate smoothly into the team.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check mentor assignments, then I should see pairings for my team members.
#       - Given a team member has a mentor, when I follow up, then they should have received guidance.
#
# ### Social Integration Tools
# - **User Stories:**
#   31. **Persona:** New Employee
#       **Feature:** Social Integration Tools
#       **User Story:** As a New Employee, I want to use social integration tools, so that I can connect with my colleagues and learn about the company culture.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access social tools, then I should see options to connect with colleagues.
#       - Given I join a social group, when I participate, then I should be able to interact with other members.
#
#   32. **Persona:** HR Manager
#       **Feature:** Social Integration Tools
#       **User Story:** As an HR Manager, I want to provide social integration tools, so that new hires can connect with their peers and feel part of the company.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable social tools, then new hires should have access to them.
#       - Given a new hire uses social tools, when I review engagement, then I should see participation metrics.
#
#   33. **Persona:** Department Manager
#       **Feature:** Social Integration Tools
#       **User Story:** As a Department Manager, I want my team to use social tools, so that they can build relationships and improve teamwork.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I encourage social tool use, then my team should have access to them.
#       - Given a team member uses social tools, when I check engagement, then I should see their participation.
#
# ### Gamification Elements
# - **User Stories:**
#   34. **Persona:** New Employee
#       **Feature:** Gamification Elements
#       **User Story:** As a New Employee, I want to earn points and badges, so that I stay motivated and engaged during onboarding.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I complete tasks, then I should earn points and badges.
#       - Given I earn a badge, when I check my profile, then it should display my achievements.
#
#   35. **Persona:** HR Manager
#       **Feature:** Gamification Elements
#       **User Story:** As an HR Manager, I want to implement gamification, so that new hires remain engaged and motivated throughout the onboarding process.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable gamification, then new hires should see points and badges for tasks.
#       - Given a new hire earns points, when I review their progress, then it should reflect their achievements.
#
#   36. **Persona:** Department Manager
#       **Feature:** Gamification Elements
#       **User Story:** As a Department Manager, I want my team to engage with gamification, so that they are motivated to complete onboarding tasks.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I promote gamification, then my team should see points and badges for tasks.
#       - Given a team member earns a badge, when I check their profile, then it should display their achievements.
#
# ### Document e-Signing
# - **User Stories:**
#   37. **Persona:** New Employee
#       **Feature:** Document e-Signing
#       **User Story:** As a New Employee, I want to e-sign documents, so that I can complete onboarding paperwork quickly and efficiently.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I receive a document, then I should be able to e-sign it.
#       - Given I e-sign a document, when I submit it, then it should be marked as completed.
#
#   38. **Persona:** HR Manager
#       **Feature:** Document e-Signing
#       **User Story:** As an HR Manager, I want new hires to e-sign documents, so that we can streamline the paperwork process.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I send a document for signing, then new hires should be able to e-sign it.
#       - Given a document is e-signed, when I check the status, then it should show as completed.
#
#   39. **Persona:** Department Manager
#       **Feature:** Document e-Signing
#       **User Story:** As a Department Manager, I want my team to complete e-signing of documents, so that we can focus on onboarding activities.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check document status, then I should see if team members have e-signed.
#       - Given a team member e-signs a document, when I review their onboarding, then it should show as completed.
#
# ### Mobile Access
# - **User Stories:**
#   40. **Persona:** New Employee
#       **Feature:** Mobile Access
#       **User Story:** As a New Employee, I want mobile access to the onboarding tool, so that I can complete tasks on the go.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access the onboarding tool on my mobile, then I should see a mobile-friendly interface.
#       - Given I complete a task on mobile, when I check my progress, then it should reflect the completion.
#
#   41. **Persona:** HR Manager
#       **Feature:** Mobile Access
#       **User Story:** As an HR Manager, I want new hires to have mobile access, so that they can complete onboarding tasks anytime, anywhere.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable mobile access, then new hires should be able to use the tool on their devices.
#       - Given a new hire completes a task on mobile, when I review their progress, then it should show as completed.
#
#   42. **Persona:** Department Manager
#       **Feature:** Mobile Access
#       **User Story:** As a Department Manager, I want my team to have mobile access, so that they can stay on top of onboarding tasks.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check mobile access, then my team should be able to use the tool on their devices.
#       - Given a team member completes a task on mobile, when I review their progress, then it should show as completed.
#
# ### Automated Reminders and Alerts
# - **User Stories:**
#   43. **Persona:** New Employee
#       **Feature:** Automated Reminders and Alerts
#       **User Story:** As a New Employee, I want to receive automated reminders, so that I don't miss any important onboarding tasks.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when a task is due soon, then I should receive a reminder notification.
#       - Given I complete a task, when I check my notifications, then the reminder should be cleared.
#
#   44. **Persona:** HR Manager
#       **Feature:** Automated Reminders and Alerts
#       **User Story:** As an HR Manager, I want to set up automated reminders, so that new hires complete tasks on time.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I configure reminders, then new hires should receive notifications for upcoming tasks.
#       - Given a task is completed, when I check the reminder status, then it should be marked as done.
#
#   45. **Persona:** Department Manager
#       **Feature:** Automated Reminders and Alerts
#       **User Story:** As a Department Manager, I want my team to receive reminders, so that they stay on track with their onboarding.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I review reminder settings, then my team should receive notifications for tasks.
#       - Given a team member completes a task, when I check their reminders, then it should be cleared.
#
# ### Multi-Language Support
# - **User Stories:**
#   46. **Persona:** New Employee
#       **Feature:** Multi-Language Support
#       **User Story:** As a New Employee, I want onboarding content in my preferred language, so that I can understand it better.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I select my preferred language, then the onboarding content should be displayed in that language.
#       - Given I switch languages, when I navigate the tool, then all content should update to the selected language.
#
#   47. **Persona:** HR Manager
#       **Feature:** Multi-Language Support
#       **User Story:** As an HR Manager, I want to provide multi-language support, so that all new hires can understand the onboarding content.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable multi-language support, then new hires should be able to select their preferred language.
#       - Given a language is selected, when I review content, then it should be available in that language.
#
#   48. **Persona:** Department Manager
#       **Feature:** Multi-Language Support
#       **User Story:** As a Department Manager, I want my team to access content in their preferred language, so that they can understand it fully.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check language settings, then my team should be able to select their preferred language.
#       - Given a team member selects a language, when I review their content, then it should be in that language.
#
# ### Video Introductions
# - **User Stories:**
#   49. **Persona:** New Employee
#       **Feature:** Video Introductions
#       **User Story:** As a New Employee, I want to watch video introductions from team members, so that I can get to know them better.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access video introductions, then I should see videos from team members.
#       - Given I watch a video, when I finish, then I should have a better understanding of the team member.
#
#   50. **Persona:** HR Manager
#       **Feature:** Video Introductions
#       **User Story:** As an HR Manager, I want to provide video introductions, so that new hires can familiarize themselves with the team.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I upload a video introduction, then it should be available to new hires.
#       - Given a new hire watches a video, when I review engagement, then I should see view metrics.
#
#   51. **Persona:** Department Manager
#       **Feature:** Video Introductions
#       **User Story:** As a Department Manager, I want my team to create video introductions, so that new hires can get to know them.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I request video introductions, then my team should be able to upload them.
#       - Given a new hire watches a video, when I check engagement, then I should see view metrics.
#
# ### Knowledge Check Quizzes
# - **User Stories:**
#   52. **Persona:** New Employee
#       **Feature:** Knowledge Check Quizzes
#       **User Story:** As a New Employee, I want to take quizzes, so that I can assess my understanding of the onboarding material.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I complete a module, then I should be prompted to take a quiz.
#       - Given I take a quiz, when I finish, then I should see my score and feedback.
#
#   53. **Persona:** HR Manager
#       **Feature:** Knowledge Check Quizzes
#       **User Story:** As an HR Manager, I want to provide quizzes, so that new hires can test their understanding of the onboarding content.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I create a quiz, then it should be available to new hires after completing a module.
#       - Given a new hire takes a quiz, when I review results, then I should see their scores and feedback.
#
#   54. **Persona:** Department Manager
#       **Feature:** Knowledge Check Quizzes
#       **User Story:** As a Department Manager, I want my team to take quizzes, so that they can confirm their understanding of the material.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check quiz availability, then my team should be able to take them after modules.
#       - Given a team member takes a quiz, when I review their results, then I should see their scores and feedback.
#
# ### Virtual Reality Tours
# - **User Stories:**
#   55. **Persona:** New Employee
#       **Feature:** Virtual Reality Tours
#       **User Story:** As a New Employee, I want to take virtual reality tours, so that I can familiarize myself with the office environment.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access the VR tour feature, then I should be able to start a virtual tour.
#       - Given I complete a tour, when I finish, then I should have a better understanding of the office layout.
#
#   56. **Persona:** HR Manager
#       **Feature:** Virtual Reality Tours
#       **User Story:** As an HR Manager, I want to offer virtual reality tours, so that new hires can explore the office remotely.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable VR tours, then new hires should have access to them.
#       - Given a new hire completes a tour, when I review engagement, then I should see participation metrics.
#
#   57. **Persona:** Department Manager
#       **Feature:** Virtual Reality Tours
#       **User Story:** As a Department Manager, I want my team to take VR tours, so that they can become familiar with the office environment.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check VR tour availability, then my team should have access to them.
#       - Given a team member completes a tour, when I review their feedback, then they should have a better understanding of the office layout.
#
# ### Customizable Templates
# - **User Stories:**
#   58. **Persona:** New Employee
#       **Feature:** Customizable Templates
#       **User Story:** As a New Employee, I want to use customizable templates, so that I can complete onboarding tasks more efficiently.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access templates, then I should see options to customize them for my tasks.
#       - Given I customize a template, when I save it, then it should be available for future use.
#
#   59. **Persona:** HR Manager
#       **Feature:** Customizable Templates
#       **User Story:** As an HR Manager, I want to provide customizable templates, so that new hires can complete tasks more efficiently.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I create a template, then it should be customizable by new hires.
#       - Given a template is customized, when I review it, then it should reflect the changes made by the new hire.
#
#   60. **Persona:** Department Manager
#       **Feature:** Customizable Templates
#       **User Story:** As a Department Manager, I want my team to use customizable templates, so that they can complete tasks more efficiently.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check template availability, then my team should be able to customize them.
#       - Given a team member customizes a template, when I review it, then it should reflect their changes.
#
# ### Peer Networking Tools
# - **User Stories:**
#   61. **Persona:** New Employee
#       **Feature:** Peer Networking Tools
#       **User Story:** As a New Employee, I want to use peer networking tools, so that I can connect with other new hires and build relationships.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access networking tools, then I should see options to connect with peers.
#       - Given I join a networking group, when I participate, then I should be able to interact with other new hires.
#
#   62. **Persona:** HR Manager
#       **Feature:** Peer Networking Tools
#       **User Story:** As an HR Manager, I want to provide peer networking tools, so that new hires can connect and build relationships.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable networking tools, then new hires should have access to them.
#       - Given a new hire uses networking tools, when I review engagement, then I should see participation metrics.
#
#   63. **Persona:** Department Manager
#       **Feature:** Peer Networking Tools
#       **User Story:** As a Department Manager, I want my team to use networking tools, so that they can connect with peers and build relationships.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I encourage networking tool use, then my team should have access to them.
#       - Given a team member uses networking tools, when I check engagement, then I should see their participation.
#
# ### Onboarding Analytics and Reporting
# - **User Stories:**
#   64. **Persona:** New Employee
#       **Feature:** Onboarding Analytics and Reporting
#       **User Story:** As a New Employee, I want to see analytics on my onboarding progress, so that I can understand how I'm doing.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access analytics, then I should see data on my onboarding progress.
#       - Given I complete a task, when I check analytics, then it should reflect the updated progress.
#
#   65. **Persona:** HR Manager
#       **Feature:** Onboarding Analytics and Reporting
#       **User Story:** As an HR Manager, I want to access onboarding analytics, so that I can evaluate the effectiveness of the onboarding process.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I access analytics, then I should see data on onboarding effectiveness.
#       - Given a new hire completes a task, when I review analytics, then it should reflect the updated progress.
#
#   66. **Persona:** Department Manager
#       **Feature:** Onboarding Analytics and Reporting
#       **User Story:** As a Department Manager, I want to see analytics on my team's onboarding, so that I can identify areas for improvement.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I access analytics, then I should see data on my team's onboarding progress.
#       - Given a team member completes a task, when I review analytics, then it should reflect the updated progress.
#
# ### Self-Service FAQs and Chatbot
# - **User Stories:**
#   67. **Persona:** New Employee
#       **Feature:** Self-Service FAQs and Chatbot
#       **User Story:** As a New Employee, I want to use a chatbot for common queries, so that I can get quick answers without waiting.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I ask a question to the chatbot, then I should receive an immediate response.
#       - Given my query is not resolved, when I request further assistance, then I should be directed to additional resources.
#
#   68. **Persona:** HR Manager
#       **Feature:** Self-Service FAQs and Chatbot
#       **User Story:** As an HR Manager, I want to provide a chatbot for common queries, so that new hires can get quick answers.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I update FAQs, then the chatbot should provide accurate responses.
#       - Given a new hire uses the chatbot, when I review engagement, then I should see query metrics.
#
#   69. **Persona:** Department Manager
#       **Feature:** Self-Service FAQs and Chatbot
#       **User Story:** As a Department Manager, I want my team to use a chatbot for queries, so that they can get quick answers and stay focused.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check chatbot availability, then my team should have access to it.
#       - Given a team member uses the chatbot, when I review engagement, then I should see query metrics.
#
# ### Task Automation
# - **User Stories:**
#   70. **Persona:** New Employee
#       **Feature:** Task Automation
#       **User Story:** As a New Employee, I want administrative tasks to be automated, so that I can focus on learning and integration.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I complete a task, then any related administrative tasks should be automated.
#       - Given an administrative task is automated, when I check my task list, then it should be marked as completed.
#
#   71. **Persona:** HR Manager
#       **Feature:** Task Automation
#       **User Story:** As an HR Manager, I want to automate administrative tasks, so that the onboarding process is more efficient.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I configure task automation, then related tasks should be automated for new hires.
#       - Given a task is automated, when I review the process, then it should show as completed without manual intervention.
#
#   72. **Persona:** Department Manager
#       **Feature:** Task Automation
#       **User Story:** As a Department Manager, I want administrative tasks to be automated, so that my team can focus on their roles.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check task automation, then my team's administrative tasks should be automated.
#       - Given a task is automated, when I review the process, then it should show as completed without manual intervention.
#
# ### Cultural Integration Modules
# - **User Stories:**
#   73. **Persona:** New Employee
#       **Feature:** Cultural Integration Modules
#       **User Story:** As a New Employee, I want to complete cultural integration modules, so that I understand the company's values and mission.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access cultural modules, then I should see content on company values and mission.
#       - Given I complete a module, when I check my progress, then it should show as completed.
#
#   74. **Persona:** HR Manager
#       **Feature:** Cultural Integration Modules
#       **User Story:** As an HR Manager, I want to provide cultural integration modules, so that new hires understand the company's values and mission.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I create a cultural module, then it should be available to new hires.
#       - Given a new hire completes a module, when I review progress, then it should show as completed.
#
#   75. **Persona:** Department Manager
#       **Feature:** Cultural Integration Modules
#       **User Story:** As a Department Manager, I want my team to complete cultural modules, so that they understand the company's values and mission.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check module availability, then my team should have access to cultural content.
#       - Given a team member completes a module, when I review their progress, then it should show as completed.
#
# ### Time Management Tools
# - **User Stories:**
#   76. **Persona:** New Employee
#       **Feature:** Time Management Tools
#       **User Story:** As a New Employee, I want to use time management tools, so that I can schedule my onboarding activities effectively.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access time management tools, then I should see options to schedule activities.
#       - Given I schedule an activity, when I check my calendar, then it should reflect the scheduled time.
#
#   77. **Persona:** HR Manager
#       **Feature:** Time Management Tools
#       **User Story:** As an HR Manager, I want to provide time management tools, so that new hires can schedule their onboarding activities.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable time management tools, then new hires should have access to them.
#       - Given a new hire schedules an activity, when I review their calendar, then it should reflect the scheduled time.
#
#   78. **Persona:** Department Manager
#       **Feature:** Time Management Tools
#       **User Story:** As a Department Manager, I want my team to use time management tools, so that they can schedule their activities effectively.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check tool availability, then my team should have access to time management tools.
#       - Given a team member schedules an activity, when I review their calendar, then it should reflect the scheduled time.
#
# ### Manager Dashboards
# - **User Stories:**
#   79. **Persona:** New Employee
#       **Feature:** Manager Dashboards
#       **User Story:** As a New Employee, I want my manager to have access to a dashboard, so that they can track my onboarding progress.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when my manager accesses the dashboard, then they should see my onboarding progress.
#       - Given I complete a task, when my manager checks the dashboard, then it should reflect the updated progress.
#
#   80. **Persona:** HR Manager
#       **Feature:** Manager Dashboards
#       **User Story:** As an HR Manager, I want managers to have access to dashboards, so that they can track their team's onboarding progress.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable manager dashboards, then managers should have access to them.
#       - Given a team member completes a task, when a manager checks the dashboard, then it should reflect the updated progress.
#
#   81. **Persona:** Department Manager
#       **Feature:** Manager Dashboards
#       **User Story:** As a Department Manager, I want access to a dashboard, so that I can track my team's onboarding progress.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I access the dashboard, then I should see my team's onboarding progress.
#       - Given a team member completes a task, when I check the dashboard, then it should reflect the updated progress.
#
# ### Access to Company News and Updates
# - **User Stories:**
#   82. **Persona:** New Employee
#       **Feature:** Access to Company News and Updates
#       **User Story:** As a New Employee, I want access to company news and updates, so that I stay informed about the organization.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access the news section, then I should see the latest company updates.
#       - Given a new update is posted, when I check the news section, then it should be visible.
#
#   83. **Persona:** HR Manager
#       **Feature:** Access to Company News and Updates
#       **User Story:** As an HR Manager, I want new hires to have access to company news, so that they stay informed about the organization.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I post a news update, then it should be visible to new hires.
#       - Given a new hire accesses the news section, when I review engagement, then I should see view metrics.
#
#   84. **Persona:** Department Manager
#       **Feature:** Access to Company News and Updates
#       **User Story:** As a Department Manager, I want my team to have access to company news, so that they stay informed about the organization.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check news availability, then my team should have access to the latest updates.
#       - Given a team member accesses the news section, when I review engagement, then I should see view metrics.
#
# ### Scenario-Based Learning
# - **User Stories:**
#   85. **Persona:** New Employee
#       **Feature:** Scenario-Based Learning
#       **User Story:** As a New Employee, I want to engage in scenario-based learning, so that I can practice real-world situations.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I access scenario-based learning, then I should see simulations relevant to my role.
#       - Given I complete a simulation, when I check my progress, then it should show as completed.
#
#   86. **Persona:** HR Manager
#       **Feature:** Scenario-Based Learning
#       **User Story:** As an HR Manager, I want to provide scenario-based learning, so that new hires can practice real-world situations.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I create a scenario, then it should be available to new hires.
#       - Given a new hire completes a simulation, when I review progress, then it should show as completed.
#
#   87. **Persona:** Department Manager
#       **Feature:** Scenario-Based Learning
#       **User Story:** As a Department Manager, I want my team to engage in scenario-based learning, so that they can practice real-world situations.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I check scenario availability, then my team should have access to simulations.
#       - Given a team member completes a simulation, when I review their progress, then it should show as completed.
#
# ### Feedback Loop with Managers
# - **User Stories:**
#   88. **Persona:** New Employee
#       **Feature:** Feedback Loop with Managers
#       **User Story:** As a New Employee, I want a feedback loop with my manager, so that I can receive guidance and support during onboarding.
#       **Acceptance Criteria:**
#       - Given I am a new employee, when I provide feedback, then my manager should be notified.
#       - Given my manager responds, when I check my feedback, then I should see their response.
#
#   89. **Persona:** HR Manager
#       **Feature:** Feedback Loop with Managers
#       **User Story:** As an HR Manager, I want to facilitate a feedback loop between new hires and managers, so that they can receive guidance and support.
#       **Acceptance Criteria:**
#       - Given I am an HR Manager, when I enable feedback loops, then new hires should be able to communicate with their managers.
#       - Given a new hire provides feedback, when I review engagement, then I should see communication metrics.
#
#   90. **Persona:** Department Manager
#       **Feature:** Feedback Loop with Managers
#       **User Story:** As a Department Manager, I want a feedback loop with my team, so that I can provide guidance and support during onboarding.
#       **Acceptance Criteria:**
#       - Given I am a Department Manager, when I receive feedback, then I should be able to respond to my team members.
#       - Given a team member provides feedback, when I review it, then I should see their comments and respond.
# ```

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating a PRD from a Template
#
# **Task:** Instead of just listing sections, we will now provide the LLM with a formal template to ensure the PRD's structure is consistent and complete.
#
# **Instructions:**
# 1. First, load the contents of `templates/prd_template.md` into a variable.
# 2. Create a new prompt that instructs the LLM to act as a Senior Product Manager.
# 3. Provide both the `user_stories_data` and the `prd_template_content` as context.
# 4. Instruct the LLM to populate the template with the information from the user stories, ensuring every section of the template is filled out.
#
# > **Tip:** The template has sections like 'Success Metrics' and 'Out of Scope' that aren't in the user stories. This is your chance to guide the LLM's creativity! Instruct it to infer logical content for these sections based on the project's overall goal.
#
# **Expected Quality:** A complete PRD that strictly follows the structure of the provided template file, demonstrating the LLM's ability to perform structured content generation.

# %%
# Load the PRD template with enhanced error handling and user-friendly messages
try:
    prd_template_content = load_artifact("templates/prd_template.md")
    if not prd_template_content:
        raise FileNotFoundError("The PRD template file is empty. Please check the file at 'templates/prd_template.md'.")
    print(f"✅ Successfully loaded PRD template ({len(prd_template_content)} characters).")
except FileNotFoundError as e:
    print(f"❌ Error: {e}")
    print("   Ensure the file exists and is not empty.")
    prd_template_content = None
except Exception as e:
    print(f"❌ An unexpected error occurred while loading the PRD template: {e}")
    print("   Please check the file path and permissions.")
    prd_template_content = None

# TODO: Write a prompt to populate the PRD template.
template_prd_prompt = f"""
You are a Senior Product Manager tasked with creating a comprehensive and formal Product Requirements Document (PRD) for a new hire onboarding tool.

Your responsibilities include:
1. Using the provided PRD template as the structure for the document.
2. Incorporating the user stories JSON data to populate relevant sections of the template.
3. Ensuring that every section of the template is completed, including sections like 'Success Metrics' and 'Out of Scope', which may not be explicitly covered in the user stories. For these sections, infer logical and reasonable content based on:
   - The overall project goal of creating a new hire onboarding tool.
   - The roles and goals of the personas described in the user stories.

Context:
<prd_template>
{prd_template_content}
</prd_template>

<user_stories_json>
{user_stories_str}
</user_stories_json>

Output:
Generate the completed PRD in markdown format. Ensure the document:
- Strictly follows the structure of the provided template.
- Is clear, concise, and professional.
- Demonstrates the ability to synthesize structured content from the provided data.
"""

print("--- Generating PRD from Template ---")
if user_stories_data and prd_template_content:
    prd_from_template_output = get_completion(template_prd_prompt, client, model_name, api_provider)
    print(prd_from_template_output)
else:
    print("Skipping PRD generation because user stories or template are missing.")
    prd_from_template_output = ""

# Diagnostic: Check template file existence and path resolution
print("=== TEMPLATE DIAGNOSTIC ===")
print("Current working directory:", os.getcwd())

# Check if templates directory exists
templates_dir = os.path.join(project_root, "templates")
print(f"Project root: {project_root}")
print(f"Templates directory: {templates_dir}")
print(f"Templates directory exists: {os.path.exists(templates_dir)}")

if os.path.exists(templates_dir):
    print("Contents of templates directory:")
    for item in os.listdir(templates_dir):
        full_path = os.path.join(templates_dir, item)
        print(f"  - {item} ({'file' if os.path.isfile(full_path) else 'directory'})")

# Check the specific template file
template_file = os.path.join(project_root, "templates", "prd_template.md")
print(f"\nPRD template file path: {template_file}")
print(f"PRD template file exists: {os.path.exists(template_file)}")

if os.path.exists(template_file):
    print(f"File size: {os.path.getsize(template_file)} bytes")
else:
    print("❌ Template file not found!")
    
print("==========================")
# Out:
# ✅ Successfully loaded PRD template (4217 characters).
# --- Generating PRD from Template ---
# ```markdown
# # Product Requirements Document: New Hire Onboarding Tool
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Senior Product Manager |
# | **Version** | 1.0 |
# | **Last Updated** | [Date] |
#
# ## 1. Executive Summary & Vision
# The New Hire Onboarding Tool is designed to streamline and enhance the onboarding experience for new employees, HR managers, and department managers. By providing a centralized platform with personalized learning paths, progress tracking, compliance modules, and integration with existing HR systems, the tool aims to improve new hire efficiency and engagement while reducing the administrative burden on HR and department managers. The ultimate vision is to create a seamless onboarding experience that accelerates new hire productivity and fosters a sense of belonging within the organization.
#
# ## 2. The Problem
#
# **2.1. Problem Statement:**
# New hires currently face a fragmented and overwhelming onboarding experience, leading to decreased initial productivity and a high volume of repetitive questions to HR and managers. This disjointed process results in inefficiencies and delays in new hires becoming fully productive members of their teams.
#
# **2.2. User Personas & Scenarios:**
#
# - **Persona 1: New Employee**
#   - Scenario: New employees struggle to navigate the onboarding process and often miss important tasks or training sessions, resulting in delays in their integration and productivity.
#
# - **Persona 2: HR Manager**
#   - Scenario: HR managers spend excessive time on manual tasks, such as tracking new hire progress and answering repetitive queries, reducing their capacity to focus on strategic HR initiatives.
#
# - **Persona 3: Department Manager**
#   - Scenario: Department managers find it challenging to track their team's onboarding progress and provide timely support, impacting the overall performance and morale of their teams.
#
# ## 3. Goals & Success Metrics
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
#
# ### Epic: Personalized Learning Paths
#
# * **Story 1.1:** As a New Employee, I want to have a personalized learning path, so that I can focus on the most relevant information for my role.
#   * **Acceptance Criteria:**
#     * **Given** I am a new employee, **when** I log into the onboarding tool, **then** I should see a personalized learning path based on my role.
#     * **Given** I have completed a module, **when** I check my progress, **then** it should reflect the completion in my learning path.
#
# * **Story 1.2:** As an HR Manager, I want to customize learning paths for new hires, so that each employee receives training relevant to their role.
#   * **Acceptance Criteria:**
#     * **Given** I am an HR Manager, **when** I create a new onboarding plan, **then** I should be able to customize learning paths based on roles.
#     * **Given** a new hire is assigned a role, **when** they start onboarding, **then** they should see a learning path tailored to their role.
#
# * **Story 1.3:** As a Department Manager, I want to ensure new hires have role-specific learning paths, so that they acquire the necessary skills quickly.
#   * **Acceptance Criteria:**
#     * **Given** I am a Department Manager, **when** I review a new hire's onboarding progress, **then** I should see their role-specific learning path.
#     * **Given** a new hire completes a module, **when** I check their progress, **then** it should show updated completion status.
#
# ### Epic: Progress Tracking Dashboard
#
# * **Story 2.1:** As a New Employee, I want to track my onboarding progress, so that I know what tasks I have completed and what is pending.
#   * **Acceptance Criteria:**
#     * **Given** I am a new employee, **when** I access the onboarding tool, **then** I should see a dashboard displaying my progress.
#     * **Given** I complete a task, **when** I refresh the dashboard, **then** it should reflect the updated progress.
#
# * **Story 2.2:** As an HR Manager, I want to monitor the progress of new hires, so that I can ensure they are on track with their onboarding.
#   * **Acceptance Criteria:**
#     * **Given** I am an HR Manager, **when** I view the onboarding dashboard, **then** I should see the progress of all new hires.
#     * **Given** a new hire completes a task, **when** I check their progress, **then** it should show the updated status.
#
# * **Story 2.3:** As a Department Manager, I want to track the onboarding progress of my team members, so that I can provide support where needed.
#   * **Acceptance Criteria:**
#     * **Given** I am a Department Manager, **when** I access the dashboard, **then** I should see the progress of new hires in my department.
#     * **Given** a new hire is behind schedule, **when** I view their progress, **then** I should be able to identify areas where they need support.
#
# ### Epic: Compliance Module
#
# * **Story 3.1:** As a New Employee, I want to complete compliance training, so that I adhere to company policies.
#   * **Acceptance Criteria:**
#     * **Given** I am a new employee, **when** I access the compliance module, **then** I should see a list of required training sessions.
#     * **Given** I complete a compliance session, **when** I check my status, **then** it should show as completed.
#
# * **Story 3.2:** As an HR Manager, I want to ensure all new hires complete compliance training, so that the organization remains compliant with regulations.
#   * **Acceptance Criteria:**
#     * **Given** I am an HR Manager, **when** I view the compliance dashboard, **then** I should see the completion status of all new hires.
#     * **Given** a new hire has not completed a session, **when** I check their compliance status, **then** it should show as pending.
#
# * **Story 3.3:** As a Department Manager, I want to verify that my team members have completed compliance training, so that we adhere to company standards.
#   * **Acceptance Criteria:**
#     * **Given** I am a Department Manager, **when** I access the compliance module, **then** I should see the training status of my team members.
#     * **Given** a team member completes a session, **when** I check their compliance status, **then** it should show as completed.
#
# (Additional user stories should follow the same format for each feature outlined in the JSON data, structured by features such as Interactive Checklists, Resource Library, Virtual Orientation Sessions, etc.)
#
# ## 5. Non-Functional Requirements (NFRs)
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection.
# - **Security:** All data must be encrypted in transit and at rest. The system must comply with company SSO policies.
# - **Accessibility:** The user interface must be compliant with WCAG 2.1 AA standards.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons.
#
# ## 6. Release Plan & Milestones
#
# - **Version 1.0 (MVP):** [Target Date] - Core features including user login, task checklist, and document repository.
# - **Version 1.1:** [Target Date] - Mentorship connection and team introduction features.
# - **Version 2.0:** [Target Date] - Full social engagement and gamification elements.
#
# ## 7. Out of Scope & Future Considerations
#
# **7.1. Out of Scope for V1.0:**
#
# - Direct integration with third-party HR payroll systems.
# - A native mobile application (the web app will be mobile-responsive).
# - Advanced analytics dashboard for managers.
#
# **7.2. Future Work:**
#
# - Integration with the corporate Learning Management System (LMS).
# - AI-powered personalized learning paths for new hires.
#
# ## 8. Appendix & Open Questions
#
# - **Open Question:** Which team will be responsible for maintaining the content in the document repository?
# - **Dependency:** The final UI design mockups are required from the Design team by [Date].
# ```
#
# === TEMPLATE DIAGNOSTIC ===
# Current working directory: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV\Labs\Day_01_Planning_and_Requirements
# Project root: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV
# Templates directory: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV\templates
# Templates directory exists: True
# Contents of templates directory:
#   - adr_template.md (file)
#   - prd_template.md (file)
#
# PRD template file path: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV\templates\prd_template.md
# PRD template file exists: True
# File size: 4297 bytes
# ==========================
# ```markdown
# # Product Requirements Document: New Hire Onboarding Tool
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Senior Product Manager |
# | **Version** | 1.0 |
# | **Last Updated** | [Date] |
#
# ## 1. Executive Summary & Vision
# The New Hire Onboarding Tool is designed to streamline and enhance the onboarding experience for new employees, HR managers, and department managers. By providing a centralized platform with personalized learning paths, progress tracking, compliance modules, and integration with existing HR systems, the tool aims to improve new hire efficiency and engagement while reducing the administrative burden on HR and department managers. The ultimate vision is to create a seamless onboarding experience that accelerates new hire productivity and fosters a sense of belonging within the organization.
#
# ## 2. The Problem
#
# **2.1. Problem Statement:**
# New hires currently face a fragmented and overwhelming onboarding experience, leading to decreased initial productivity and a high volume of repetitive questions to HR and managers. This disjointed process results in inefficiencies and delays in new hires becoming fully productive members of their teams.
#
# **2.2. User Personas & Scenarios:**
#
# - **Persona 1: New Employee**
#   - Scenario: New employees struggle to navigate the onboarding process and often miss important tasks or training sessions, resulting in delays in their integration and productivity.
#
# - **Persona 2: HR Manager**
#   - Scenario: HR managers spend excessive time on manual tasks, such as tracking new hire progress and answering repetitive queries, reducing their capacity to focus on strategic HR initiatives.
#
# - **Persona 3: Department Manager**
#   - Scenario: Department managers find it challenging to track their team's onboarding progress and provide timely support, impacting the overall performance and morale of their teams.
#
# ## 3. Goals & Success Metrics
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
#
# ### Epic: Personalized Learning Paths
#
# * **Story 1.1:** As a New Employee, I want to have a personalized learning path, so that I can focus on the most relevant information for my role.
#   * **Acceptance Criteria:**
#     * **Given** I am a new employee, **when** I log into the onboarding tool, **then** I should see a personalized learning path based on my role.
#     * **Given** I have completed a module, **when** I check my progress, **then** it should reflect the completion in my learning path.
#
# * **Story 1.2:** As an HR Manager, I want to customize learning paths for new hires, so that each employee receives training relevant to their role.
#   * **Acceptance Criteria:**
#     * **Given** I am an HR Manager, **when** I create a new onboarding plan, **then** I should be able to customize learning paths based on roles.
#     * **Given** a new hire is assigned a role, **when** they start onboarding, **then** they should see a learning path tailored to their role.
#
# * **Story 1.3:** As a Department Manager, I want to ensure new hires have role-specific learning paths, so that they acquire the necessary skills quickly.
#   * **Acceptance Criteria:**
#     * **Given** I am a Department Manager, **when** I review a new hire's onboarding progress, **then** I should see their role-specific learning path.
#     * **Given** a new hire completes a module, **when** I check their progress, **then** it should show updated completion status.
#
# ### Epic: Progress Tracking Dashboard
#
# * **Story 2.1:** As a New Employee, I want to track my onboarding progress, so that I know what tasks I have completed and what is pending.
#   * **Acceptance Criteria:**
#     * **Given** I am a new employee, **when** I access the onboarding tool, **then** I should see a dashboard displaying my progress.
#     * **Given** I complete a task, **when** I refresh the dashboard, **then** it should reflect the updated progress.
#
# * **Story 2.2:** As an HR Manager, I want to monitor the progress of new hires, so that I can ensure they are on track with their onboarding.
#   * **Acceptance Criteria:**
#     * **Given** I am an HR Manager, **when** I view the onboarding dashboard, **then** I should see the progress of all new hires.
#     * **Given** a new hire completes a task, **when** I check their progress, **then** it should show the updated status.
#
# * **Story 2.3:** As a Department Manager, I want to track the onboarding progress of my team members, so that I can provide support where needed.
#   * **Acceptance Criteria:**
#     * **Given** I am a Department Manager, **when** I access the dashboard, **then** I should see the progress of new hires in my department.
#     * **Given** a new hire is behind schedule, **when** I view their progress, **then** I should be able to identify areas where they need support.
#
# ### Epic: Compliance Module
#
# * **Story 3.1:** As a New Employee, I want to complete compliance training, so that I adhere to company policies.
#   * **Acceptance Criteria:**
#     * **Given** I am a new employee, **when** I access the compliance module, **then** I should see a list of required training sessions.
#     * **Given** I complete a compliance session, **when** I check my status, **then** it should show as completed.
#
# * **Story 3.2:** As an HR Manager, I want to ensure all new hires complete compliance training, so that the organization remains compliant with regulations.
#   * **Acceptance Criteria:**
#     * **Given** I am an HR Manager, **when** I view the compliance dashboard, **then** I should see the completion status of all new hires.
#     * **Given** a new hire has not completed a session, **when** I check their compliance status, **then** it should show as pending.
#
# * **Story 3.3:** As a Department Manager, I want to verify that my team members have completed compliance training, so that we adhere to company standards.
#   * **Acceptance Criteria:**
#     * **Given** I am a Department Manager, **when** I access the compliance module, **then** I should see the training status of my team members.
#     * **Given** a team member completes a session, **when** I check their compliance status, **then** it should show as completed.
#
# (Additional user stories should follow the same format for each feature outlined in the JSON data, structured by features such as Interactive Checklists, Resource Library, Virtual Orientation Sessions, etc.)
#
# ## 5. Non-Functional Requirements (NFRs)
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection.
# - **Security:** All data must be encrypted in transit and at rest. The system must comply with company SSO policies.
# - **Accessibility:** The user interface must be compliant with WCAG 2.1 AA standards.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons.
#
# ## 6. Release Plan & Milestones
#
# - **Version 1.0 (MVP):** [Target Date] - Core features including user login, task checklist, and document repository.
# - **Version 1.1:** [Target Date] - Mentorship connection and team introduction features.
# - **Version 2.0:** [Target Date] - Full social engagement and gamification elements.
#
# ## 7. Out of Scope & Future Considerations
#
# **7.1. Out of Scope for V1.0:**
#
# - Direct integration with third-party HR payroll systems.
# - A native mobile application (the web app will be mobile-responsive).
# - Advanced analytics dashboard for managers.
#
# **7.2. Future Work:**
#
# - Integration with the corporate Learning Management System (LMS).
# - AI-powered personalized learning paths for new hires.
#
# ## 8. Appendix & Open Questions
#
# - **Open Question:** Which team will be responsible for maintaining the content in the document repository?
# - **Dependency:** The final UI design mockups are required from the Design team by [Date].
# ```
#
# === TEMPLATE DIAGNOSTIC ===
# Current working directory: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV\Labs\Day_01_Planning_and_Requirements
# Project root: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV
# Templates directory: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV\templates
# Templates directory exists: True
# Contents of templates directory:
#   - adr_template.md (file)
#   - prd_template.md (file)
#
# PRD template file path: c:\Users\labadmin\Desktop\AISWE\AG-AISOFTDEV\templates\prd_template.md
# PRD template file exists: True
# File size: 4297 bytes
# ==========================

# %% [markdown]
# ### Challenge 3 (Advanced): Programmatic Validation with Pydantic
#
# **Task:** We will now create a Pydantic model to represent the structure of our PRD. This allows us to programmatically validate any PRD, ensuring it meets our standards before it's accepted as a formal artifact.
#
# **Instructions:**
# 1.  Prompt the LLM to generate a Pydantic model that reflects the structure of the `prd_template.md`. The model should have fields for each major section (e.g., `introduction: str`, `user_personas: List[str]`, `user_stories: List[Dict]`).
# 2.  Save this generated model code to a file named `app/validation_models/prd_model.py`.
# 3.  While we won't write the full validation script in this lab, generating the Pydantic model itself is the key advanced step. It creates a reusable, code-based standard for our documentation.
#
# **Expected Quality:** A Python file containing a valid Pydantic model that can be used in the future to validate PRD documents automatically. This represents a shift from manual document review to automated governance.

# %%
# TODO: Write a prompt to generate a Pydantic model for the PRD.
# Tip: Be specific. Tell the LLM to create a class named 'ProductRequirementsDocument' and to use appropriate types from Python's 'typing' library.
pydantic_model_prompt = f"""
# Your prompt here
"""

print("--- Generating Pydantic Model for PRD ---")
if prd_template_content:
    pydantic_model_code = get_completion(pydantic_model_prompt, client, model_name, api_provider)
    
    # Clean up the code if it's wrapped in markdown fences
    if '```' in pydantic_model_code:
        pydantic_model_code = pydantic_model_code.split('```')[1].lstrip('python').strip()
    
    print("\n--- Generated Pydantic Model ---")
    print(pydantic_model_code)

    # Save the generated Pydantic model code to a file.
    model_path = "app/validation_models/prd_model.py"
    save_artifact(pydantic_model_code, model_path)
else:
    print("Skipping Pydantic model generation because template is missing.")

# Finally, save the completed PRD from the intermediate challenge
if prd_from_template_output:
    save_artifact(prd_from_template_output, "artifacts/day1_prd.md")

# %% [markdown]
# ## Lab Conclusion
#
# Excellent work! You have now taken the structured user stories from the first lab and synthesized them into a formal Product Requirements Document. You also created a Pydantic model to enforce the structure of this document, introducing automated governance into your workflow. The `day1_prd.md` artifact will be the primary input for Day 2, where we will begin designing our system's architecture and database.
#
# > **Key Takeaway:** Using an LLM to populate a pre-defined template is a powerful pattern for creating consistent, high-quality documentation at scale. It combines the LLM's language skills with your required structure.
